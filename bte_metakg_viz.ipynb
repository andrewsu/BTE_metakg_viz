# %% [markdown]
# # BTE metakg visualization
#
# The goal of this notebook is to visualize the metaKG that BTE uses.  Similar to the [subway diagram](https://raw.githubusercontent.com/biothings/BioThings_Explorer_TRAPI/main/diagrams/smartapi_metagraph.png) we've used before, but updated to the size and scale of the current metakg.
#
# Optimizations
# * remove less-commonly-used node types from subject/object
# * only count in one direction (`A-treats-B` gets merged with `B-treated_by-A`)

# %%
import biothings_client
import json5
import networkx as nx
import pandas as pd
import re
import requests

# %% [markdown]
# ## Read in SmartAPI data

# %% [markdown]
# ### Option 1 -- Read in the Smart API ndjson file

# %%
# older input file from Chunlei
#df = pd.read_json('data/smartapi_metakg_20230413.ndjson.gz', lines=True)

# newer input file from Chunlei -- preprocessed using following command:
#      gzip -cd smartapi_metakg_20230413.ndjson.gz | jq -c ' ._source' | gzip > smartapi_metakg_20230413b.ndjson.gz
df = pd.read_json('data/smartapi_metakg_20230413b.ndjson.gz', lines=True)
df
# Out:
#                      subject            object               predicate  \
# 0                    Disease           Disease           superclass_of
# 1            SequenceVariant              Gene  is_sequence_variant_of
# 2          GeneOrGeneProduct    ChemicalEntity                has_part
# 3          NucleicAcidEntity    ChemicalEntity                has_part
# 4             ChemicalEntity    ChemicalEntity                has_part
# ...                      ...               ...                     ...
# 367201    GeographicLocation         Procedure            derives_from
# 367202  ClinicalIntervention          Activity              related_to
# 367203           Polypeptide  AnatomicalEntity           coexists_with
# 367204            NamedThing        Phenomenon                has_part
# 367205                 Agent             Agent                  treats
#
#                      provided_by  \
# 0       infores:disease-ontology
# 1                  infores:dbsnp
# 2                            NaN
# 3                            NaN
# 4                            NaN
# ...                          ...
# 367201                       NaN
# 367202                       NaN
# 367203                       NaN
# 367204                       NaN
# 367205                       NaN
#
#                                                       api  \
# 0       {'name': 'Ontology Lookup Service API', 'smart...
# 1       {'name': 'LitVar API', 'smartapi': {'metadata'...
# 2       {'name': 'Ontology-KP API', 'smartapi': {'meta...
# 3       {'name': 'Ontology-KP API', 'smartapi': {'meta...
# 4       {'name': 'Ontology-KP API', 'smartapi': {'meta...
# ...                                                   ...
# 367201  {'name': 'ARAX Translator Reasoner - TRAPI 1.3...
# 367202  {'name': 'ARAX Translator Reasoner - TRAPI 1.3...
# 367203  {'name': 'ARAX Translator Reasoner - TRAPI 1.3...
# 367204  {'name': 'ARAX Translator Reasoner - TRAPI 1.3...
# 367205  {'name': 'ARAX Translator Reasoner - TRAPI 1.3...
#
#                                                       bte
# 0       {'query_operation': {'params': {'id': '{{ quer...
# 1       {'query_operation': {'params': {'variantid': '...
# 2       {'query_operation': {'path': '/query', 'method...
# 3       {'query_operation': {'path': '/query', 'method...
# 4       {'query_operation': {'path': '/query', 'method...
# ...                                                   ...
# 367201  {'query_operation': {'path': '/query', 'method...
# 367202  {'query_operation': {'path': '/query', 'method...
# 367203  {'query_operation': {'path': '/query', 'method...
# 367204  {'query_operation': {'path': '/query', 'method...
# 367205  {'query_operation': {'path': '/query', 'method...
#
# [367206 rows x 6 columns]

# %% [markdown]
# ### Option 2 (preferred) -- Query the SmartAPI API
#
# This method takes longer, but it retrieves the most up-to-date data

# %%
c = biothings_client.get_client('metakg', url='https://smart-api.info/api/metakg')
c._query_endpoint=''
a = c.query('*', fetch_all=True)

# %%
df = pd.DataFrame(a)
df
# Out:
# Fetching 183941 metakg(s) . . .
# No more results to return.
#                          _id  _score  \
# 0       54derYkBXoKXcforKZub     1.0
# 1       6IderYkBXoKXcforKZub     1.0
# 2       6YderYkBXoKXcforKZub     1.0
# 3       6oderYkBXoKXcforKZub     1.0
# 4       64derYkBXoKXcforKZub     1.0
# ...                      ...     ...
# 183936  Z4pgrYkBXoKXcforP2oX     1.0
# 183937  aIpgrYkBXoKXcforP2oX     1.0
# 183938  aYpgrYkBXoKXcforP2oX     1.0
# 183939  aopgrYkBXoKXcforP2oX     1.0
# 183940  a4pgrYkBXoKXcforP2oX     1.0
#
#                                                       api              object  \
# 0       {'name': 'CTD API', 'smartapi': {'id': '021261...                Gene
# 1       {'name': 'CTD API', 'smartapi': {'id': '021261...       SmallMolecule
# 2       {'name': 'CTD API', 'smartapi': {'id': '021261...       SmallMolecule
# 3       {'name': 'CTD API', 'smartapi': {'id': '021261...       SmallMolecule
# 4       {'name': 'CTD API', 'smartapi': {'id': '021261...   BiologicalProcess
# ...                                                   ...                 ...
# 183936  {'name': 'ARAX Translator Reasoner - TRAPI 1.4...               Agent
# 183937  {'name': 'ARAX Translator Reasoner - TRAPI 1.4...                Gene
# 183938  {'name': 'ARAX Translator Reasoner - TRAPI 1.4...  IndividualOrganism
# 183939  {'name': 'ARAX Translator Reasoner - TRAPI 1.4...            Activity
# 183940  {'name': 'ARAX Translator Reasoner - TRAPI 1.4...             Disease
#
#                                  predicate                     subject  \
# 0                               related_to               SmallMolecule
# 1                               related_to                        Gene
# 2                               related_to                     Disease
# 3                               related_to                     Disease
# 4                               related_to               SmallMolecule
# ...                                    ...                         ...
# 183936                             affects  DiseaseOrPhenotypicFeature
# 183937  directly_physically_interacts_with                        Gene
# 183938                            disrupts             MolecularEntity
# 183939                           occurs_in          GeneticInheritance
# 183940                              treats                  RNAProduct
#
#        provided_by
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
# ...            ...
# 183936         NaN
# 183937         NaN
# 183938         NaN
# 183939         NaN
# 183940         NaN
#
# [183941 rows x 7 columns]

# %% [markdown]
# ### Post-processing

# %% [markdown]
# parse out a couple lines for the API name and ID

# %%
df = df.assign(api_name = lambda x: pd.json_normalize(x['api'])['name'])
df = df.assign(api_id = lambda x: pd.json_normalize(x['api'])['smartapi.id'])
df
# Out:
#                          _id  _score  \
# 0       54derYkBXoKXcforKZub     1.0
# 1       6IderYkBXoKXcforKZub     1.0
# 2       6YderYkBXoKXcforKZub     1.0
# 3       6oderYkBXoKXcforKZub     1.0
# 4       64derYkBXoKXcforKZub     1.0
# ...                      ...     ...
# 183936  Z4pgrYkBXoKXcforP2oX     1.0
# 183937  aIpgrYkBXoKXcforP2oX     1.0
# 183938  aYpgrYkBXoKXcforP2oX     1.0
# 183939  aopgrYkBXoKXcforP2oX     1.0
# 183940  a4pgrYkBXoKXcforP2oX     1.0
#
#                                                       api              object  \
# 0       {'name': 'CTD API', 'smartapi': {'id': '021261...                Gene
# 1       {'name': 'CTD API', 'smartapi': {'id': '021261...       SmallMolecule
# 2       {'name': 'CTD API', 'smartapi': {'id': '021261...       SmallMolecule
# 3       {'name': 'CTD API', 'smartapi': {'id': '021261...       SmallMolecule
# 4       {'name': 'CTD API', 'smartapi': {'id': '021261...   BiologicalProcess
# ...                                                   ...                 ...
# 183936  {'name': 'ARAX Translator Reasoner - TRAPI 1.4...               Agent
# 183937  {'name': 'ARAX Translator Reasoner - TRAPI 1.4...                Gene
# 183938  {'name': 'ARAX Translator Reasoner - TRAPI 1.4...  IndividualOrganism
# 183939  {'name': 'ARAX Translator Reasoner - TRAPI 1.4...            Activity
# 183940  {'name': 'ARAX Translator Reasoner - TRAPI 1.4...             Disease
#
#                                  predicate                     subject  \
# 0                               related_to               SmallMolecule
# 1                               related_to                        Gene
# 2                               related_to                     Disease
# 3                               related_to                     Disease
# 4                               related_to               SmallMolecule
# ...                                    ...                         ...
# 183936                             affects  DiseaseOrPhenotypicFeature
# 183937  directly_physically_interacts_with                        Gene
# 183938                            disrupts             MolecularEntity
# 183939                           occurs_in          GeneticInheritance
# 183940                              treats                  RNAProduct
#
#        provided_by                                api_name  \
# 0              NaN                                 CTD API
# 1              NaN                                 CTD API
# 2              NaN                                 CTD API
# 3              NaN                                 CTD API
# 4              NaN                                 CTD API
# ...            ...                                     ...
# 183936         NaN  ARAX Translator Reasoner - TRAPI 1.4.0
# 183937         NaN  ARAX Translator Reasoner - TRAPI 1.4.0
# 183938         NaN  ARAX Translator Reasoner - TRAPI 1.4.0
# 183939         NaN  ARAX Translator Reasoner - TRAPI 1.4.0
# 183940         NaN  ARAX Translator Reasoner - TRAPI 1.4.0
#
#                                   api_id
# 0       0212611d1c670f9107baf00b77f0889a
# 1       0212611d1c670f9107baf00b77f0889a
# 2       0212611d1c670f9107baf00b77f0889a
# 3       0212611d1c670f9107baf00b77f0889a
# 4       0212611d1c670f9107baf00b77f0889a
# ...                                  ...
# 183936  283042abacfe3c6bcdc924c4a226ff98
# 183937  283042abacfe3c6bcdc924c4a226ff98
# 183938  283042abacfe3c6bcdc924c4a226ff98
# 183939  283042abacfe3c6bcdc924c4a226ff98
# 183940  283042abacfe3c6bcdc924c4a226ff98
#
# [183941 rows x 9 columns]

# %% [markdown]
# ## Read in the BTE config file that specifies currently-allowed APIs

# %%
bte_config_url = "https://raw.githubusercontent.com/biothings/BioThings_Explorer_TRAPI/main/src/config/apis.js"
r = requests.get(bte_config_url)
str_bte_config = r.text
#print(str_bte_config)
str_bte_config = re.sub("exports.API_LIST = ",  "", str_bte_config)                       # remove variable assignment step
str_bte_config = re.sub("\s*//.*",              "", str_bte_config)                       # remove commented lines
str_bte_config = re.sub(r'^$\n',                '', str_bte_config, flags=re.MULTILINE)   # remove blank lines
str_bte_config = re.sub(r',\s*exclude:[^\]]*]', '', str_bte_config, flags=re.MULTILINE)   # remove 'exclude' section
str_bte_config = re.sub(r';$',                  '', str_bte_config, flags=re.MULTILINE)   # remove 'exclude' section
#print(str_bte_config)

bte_config = json5.loads(str_bte_config)['include']
bte_config
# Out:
# [{'id': 'd22b657426375a5295e7da8a303b9893', 'name': 'BioLink API'},
#  {'id': '0212611d1c670f9107baf00b77f0889a',
#   'name': 'CTD API',
#   'primarySource': True},
#  {'id': '43af91b3d7cae43591083bff9d75c6dd', 'name': 'EBI Proteins API'},
#  {'id': 'dca415f2d792976af9d642b7e73f7a41', 'name': 'LitVar API'},
#  {'id': '1f277e1563fcfd124bfae2cc3c4bcdec', 'name': 'QuickGO API'},
#  {'id': '1c056ffc7ed0dd1229e71c4752239465',
#   'name': 'Ontology Lookup Service API'},
#  {'id': '38e9e5169a72aee3659c9ddba956790d', 'name': 'BioThings BindingDB API'},
#  {'id': '55a223c6c6e0291dbd05f2faf27d16f4',
#   'name': 'BioThings BioPlanet Pathway-Disease API'},
#  {'id': 'b99c6dd64abcefe87dcd0a51c249ee6d',
#   'name': 'BioThings BioPlanet Pathway-Gene API'},
#  {'id': '00fb85fc776279163199e6c50f6ddfc6', 'name': 'BioThings DDInter API'},
#  {'id': 'e3edd325c76f2992a111b43a907a4870', 'name': 'BioThings DGIdb API'},
#  {'id': 'a7f784626a426d054885a5f33f17d3f8', 'name': 'BioThings DISEASES API'},
#  {'id': '1f47552dabd67351d4c625adb0a10d00',
#   'name': 'BioThings EBIgene2phenotype API'},
#  {'id': 'cc857d5b7c8b7609b5bbb38ff990bfff',
#   'name': 'BioThings GO Biological Process API'},
#  {'id': 'f339b28426e7bf72028f60feefcd7465',
#   'name': 'BioThings GO Cellular Component API'},
#  {'id': '34bad236d77bea0a0ee6c6cba5be54a6',
#   'name': 'BioThings GO Molecular Function API'},
#  {'id': '316eab811fd9ef1097df98bcaa9f7361', 'name': 'BioThings GTRx API'},
#  {'id': 'a5b0ec6bfde5008984d4b6cde402d61f', 'name': 'BioThings HPO API'},
#  {'id': '32f36164fabed5d3abe6c2fd899c9418', 'name': 'BioThings IDISK API'},
#  {'id': '77ed27f111262d0289ed4f4071faa619',
#   'name': 'BioThings MGIgene2phenotype API'},
#  {'id': 'edeb26858bd27d0322af93e7a9e08761', 'name': 'BioThings PFOCR API'},
#  {'id': 'b772ebfbfa536bba37764d7fddb11d6f',
#   'name': 'BioThings RARe-SOURCE API'},
#  {'id': '03283cc2b21c077be6794e1704b1d230', 'name': 'BioThings Rhea API'},
#  {'id': '1d288b3a3caf75d541ffaae3aab386c8', 'name': 'BioThings SEMMEDDB API'},
#  {'id': 'ec6d76016ef40f284359d17fbf78df20', 'name': 'BioThings UBERON API'},
#  {'id': '8f08d1446e0bb9c2b323713ce83e2bd3', 'name': 'MyChem.info API'},
#  {'id': '671b45c0301c8624abbd26ae78449ca2', 'name': 'MyDisease.info API'},
#  {'id': '59dce17363dce279d389100834e43648', 'name': 'MyGene.info API'},
#  {'id': '09c8782d9f4027712e65b95424adba79', 'name': 'MyVariant.info API'},
#  {'id': 'adf20dd6ff23dfe18e8e012bde686e31',
#   'name': 'Multiomics BigGIM-DrugResponse KP API'},
#  {'id': '08a5ddcde71b4bf838327ef469076acd',
#   'name': 'Multiomics ClinicalTrials KP'},
#  {'id': 'd86a24f6027ffe778f84ba10a7a1861a',
#   'name': 'Multiomics EHR Risk KP API'},
#  {'id': '02af7d098ab304e80d6f4806c3527027',
#   'name': 'Multiomics Wellness KP API'},
#  {'id': '978fe380a147a8641caf72320862697b',
#   'name': 'Text Mining Targeted Association API'},
#  {'id': 'ef0656900ff73f861611bcad87a94bce',
#   'name': 'Automat-biolink(Trapi v1.4.0)'},
#  {'id': '97da45e75266b021fae885735befad07',
#   'name': 'Automat-ctd(Trapi v1.4.0)'},
#  {'id': 'a80b9c70e756453d1ce8971b59fe1778',
#   'name': 'Automat-drug-central(Trapi v1.4.0)'},
#  {'id': '2575e053d0a631433b447995e1bc9602',
#   'name': 'Automat-gtex(Trapi v1.4.0)'},
#  {'id': '387f7a2c21656ddfcce5ccf9ea459049',
#   'name': 'Automat-gtopdb(Trapi v1.4.0)'},
#  {'id': 'cd9fc0ca8cc6d9f56bd56a34766de791',
#   'name': 'Automat-gwas-catalog(Trapi v1.4.0)'},
#  {'id': '8a1e2c2eade9fe3a932ba1dbb7f85688',
#   'name': 'Automat-hetio(Trapi v1.4.0)'},
#  {'id': '067d3a847117c6f42896cc8cd140a704',
#   'name': 'Automat-hgnc(Trapi v1.4.0)'},
#  {'id': '0658e8749b9601a5faba5157ba12eb06',
#   'name': 'Automat-hmdb(Trapi v1.4.0)'},
#  {'id': '43cf256c660cc5bdeac23fdd3063d474',
#   'name': 'Automat-human-goa(Trapi v1.4.0)'},
#  {'id': '76a164ff43e7ab39a5b98a782f6361bf',
#   'name': 'Automat-icees-kg(Trapi v1.4.0)'},
#  {'id': '0b0a4d48ccd9ad2fd34ee53c34f87e94',
#   'name': 'Automat-intact(Trapi v1.4.0)'},
#  {'id': '26ca4939d437c411bcb65b85a9dc2b99',
#   'name': 'Automat-panther(Trapi v1.4.0)'},
#  {'id': '1c71f68839a44b1b857e79ae7f7e3381',
#   'name': 'Automat-pharos(Trapi v1.4.0)'},
#  {'id': '465ff6de7ddf35ca8b2df6c0b01e6554',
#   'name': 'Automat-viral-proteome(Trapi v1.4.0)'},
#  {'id': 'af364143267ad5235bf78c1511223875', 'name': 'COHD TRAPI'},
#  {'id': '23f770568b92b7a82063989b3ddd9706',
#   'name': 'Connections Hypothesis Provider API'}]

# %%
bte_config_notrapi = [ item for item in bte_config if not re.search("trapi", item['name'], re.IGNORECASE)]

# temporary hack on next line pending merge of https://github.com/biothings/biothings_explorer/pull/624
bte_config_notrapi = [ item for item in bte_config_notrapi if item['name'] != "Connections Hypothesis Provider API" ]

bte_config_notrapi
# Out:
# [{'id': 'd22b657426375a5295e7da8a303b9893', 'name': 'BioLink API'},
#  {'id': '0212611d1c670f9107baf00b77f0889a',
#   'name': 'CTD API',
#   'primarySource': True},
#  {'id': '43af91b3d7cae43591083bff9d75c6dd', 'name': 'EBI Proteins API'},
#  {'id': 'dca415f2d792976af9d642b7e73f7a41', 'name': 'LitVar API'},
#  {'id': '1f277e1563fcfd124bfae2cc3c4bcdec', 'name': 'QuickGO API'},
#  {'id': '1c056ffc7ed0dd1229e71c4752239465',
#   'name': 'Ontology Lookup Service API'},
#  {'id': '38e9e5169a72aee3659c9ddba956790d', 'name': 'BioThings BindingDB API'},
#  {'id': '55a223c6c6e0291dbd05f2faf27d16f4',
#   'name': 'BioThings BioPlanet Pathway-Disease API'},
#  {'id': 'b99c6dd64abcefe87dcd0a51c249ee6d',
#   'name': 'BioThings BioPlanet Pathway-Gene API'},
#  {'id': '00fb85fc776279163199e6c50f6ddfc6', 'name': 'BioThings DDInter API'},
#  {'id': 'e3edd325c76f2992a111b43a907a4870', 'name': 'BioThings DGIdb API'},
#  {'id': 'a7f784626a426d054885a5f33f17d3f8', 'name': 'BioThings DISEASES API'},
#  {'id': '1f47552dabd67351d4c625adb0a10d00',
#   'name': 'BioThings EBIgene2phenotype API'},
#  {'id': 'cc857d5b7c8b7609b5bbb38ff990bfff',
#   'name': 'BioThings GO Biological Process API'},
#  {'id': 'f339b28426e7bf72028f60feefcd7465',
#   'name': 'BioThings GO Cellular Component API'},
#  {'id': '34bad236d77bea0a0ee6c6cba5be54a6',
#   'name': 'BioThings GO Molecular Function API'},
#  {'id': '316eab811fd9ef1097df98bcaa9f7361', 'name': 'BioThings GTRx API'},
#  {'id': 'a5b0ec6bfde5008984d4b6cde402d61f', 'name': 'BioThings HPO API'},
#  {'id': '32f36164fabed5d3abe6c2fd899c9418', 'name': 'BioThings IDISK API'},
#  {'id': '77ed27f111262d0289ed4f4071faa619',
#   'name': 'BioThings MGIgene2phenotype API'},
#  {'id': 'edeb26858bd27d0322af93e7a9e08761', 'name': 'BioThings PFOCR API'},
#  {'id': 'b772ebfbfa536bba37764d7fddb11d6f',
#   'name': 'BioThings RARe-SOURCE API'},
#  {'id': '03283cc2b21c077be6794e1704b1d230', 'name': 'BioThings Rhea API'},
#  {'id': '1d288b3a3caf75d541ffaae3aab386c8', 'name': 'BioThings SEMMEDDB API'},
#  {'id': 'ec6d76016ef40f284359d17fbf78df20', 'name': 'BioThings UBERON API'},
#  {'id': '8f08d1446e0bb9c2b323713ce83e2bd3', 'name': 'MyChem.info API'},
#  {'id': '671b45c0301c8624abbd26ae78449ca2', 'name': 'MyDisease.info API'},
#  {'id': '59dce17363dce279d389100834e43648', 'name': 'MyGene.info API'},
#  {'id': '09c8782d9f4027712e65b95424adba79', 'name': 'MyVariant.info API'},
#  {'id': 'adf20dd6ff23dfe18e8e012bde686e31',
#   'name': 'Multiomics BigGIM-DrugResponse KP API'},
#  {'id': '08a5ddcde71b4bf838327ef469076acd',
#   'name': 'Multiomics ClinicalTrials KP'},
#  {'id': 'd86a24f6027ffe778f84ba10a7a1861a',
#   'name': 'Multiomics EHR Risk KP API'},
#  {'id': '02af7d098ab304e80d6f4806c3527027',
#   'name': 'Multiomics Wellness KP API'},
#  {'id': '978fe380a147a8641caf72320862697b',
#   'name': 'Text Mining Targeted Association API'}]

# %%
# uncomment one of the following two lines to look at all APIs, or just x-bte APIs
#bte_config_ids = [ x['id'] for x in bte_config ]
bte_config_ids = [ x['id'] for x in bte_config_notrapi ]

print(len(bte_config_ids))
print(bte_config_ids)
# Out:
# 34
# ['d22b657426375a5295e7da8a303b9893', '0212611d1c670f9107baf00b77f0889a', '43af91b3d7cae43591083bff9d75c6dd', 'dca415f2d792976af9d642b7e73f7a41', '1f277e1563fcfd124bfae2cc3c4bcdec', '1c056ffc7ed0dd1229e71c4752239465', '38e9e5169a72aee3659c9ddba956790d', '55a223c6c6e0291dbd05f2faf27d16f4', 'b99c6dd64abcefe87dcd0a51c249ee6d', '00fb85fc776279163199e6c50f6ddfc6', 'e3edd325c76f2992a111b43a907a4870', 'a7f784626a426d054885a5f33f17d3f8', '1f47552dabd67351d4c625adb0a10d00', 'cc857d5b7c8b7609b5bbb38ff990bfff', 'f339b28426e7bf72028f60feefcd7465', '34bad236d77bea0a0ee6c6cba5be54a6', '316eab811fd9ef1097df98bcaa9f7361', 'a5b0ec6bfde5008984d4b6cde402d61f', '32f36164fabed5d3abe6c2fd899c9418', '77ed27f111262d0289ed4f4071faa619', 'edeb26858bd27d0322af93e7a9e08761', 'b772ebfbfa536bba37764d7fddb11d6f', '03283cc2b21c077be6794e1704b1d230', '1d288b3a3caf75d541ffaae3aab386c8', 'ec6d76016ef40f284359d17fbf78df20', '8f08d1446e0bb9c2b323713ce83e2bd3', '671b45c0301c8624abbd26ae78449ca2', '59dce17363dce279d389100834e43648', '09c8782d9f4027712e65b95424adba79', 'adf20dd6ff23dfe18e8e012bde686e31', '08a5ddcde71b4bf838327ef469076acd', 'd86a24f6027ffe778f84ba10a7a1861a', '02af7d098ab304e80d6f4806c3527027', '978fe380a147a8641caf72320862697b']

# %% [markdown]
# ## Join SmartAPI data with BTE config IDs

# %%
df_bte = df.query('api_id in @bte_config_ids')[['subject','object','predicate','api_name','api_id']].drop_duplicates().sort_values(['api_name','subject','object','predicate'])
df_bte
# Out:
#               subject             object                       predicate  \
# 161530        Disease               Gene                       caused_by
# 161531        Disease               Gene  condition_associated_with_gene
# 161532        Disease            Pathway               actively_involves
# 161533        Disease  PhenotypicFeature                   has_phenotype
# 161534        Disease    SequenceVariant               contribution_from
# ...               ...                ...                             ...
# 161568  SmallMolecule            Disease                  contributes_to
# 161550  SmallMolecule            Disease                          treats
# 161554  SmallMolecule               Gene                         affects
# 161566  SmallMolecule  PhenotypicFeature                  contributes_to
# 161552  SmallMolecule  PhenotypicFeature                          treats
#
#                                     api_name                            api_id
# 161530                           BioLink API  d22b657426375a5295e7da8a303b9893
# 161531                           BioLink API  d22b657426375a5295e7da8a303b9893
# 161532                           BioLink API  d22b657426375a5295e7da8a303b9893
# 161533                           BioLink API  d22b657426375a5295e7da8a303b9893
# 161534                           BioLink API  d22b657426375a5295e7da8a303b9893
# ...                                      ...                               ...
# 161568  Text Mining Targeted Association API  978fe380a147a8641caf72320862697b
# 161550  Text Mining Targeted Association API  978fe380a147a8641caf72320862697b
# 161554  Text Mining Targeted Association API  978fe380a147a8641caf72320862697b
# 161566  Text Mining Targeted Association API  978fe380a147a8641caf72320862697b
# 161552  Text Mining Targeted Association API  978fe380a147a8641caf72320862697b
#
# [1033 rows x 5 columns]

# %%
df_bte.to_csv("results/bte_operations.tsv", sep="\t", index=False)

# %% [markdown]
# Note: `bte_operations.tsv` is included in the paper as a Supplemental Table

# %%
df_bte['api_name'].value_counts()
# Out:
# BioThings SEMMEDDB API                     826
# BioLink API                                 21
# Text Mining Targeted Association API        20
# MyDisease.info API                          17
# Multiomics EHR Risk KP API                  14
# Multiomics BigGIM-DrugResponse KP API       14
# MyChem.info API                             12
# MyGene.info API                             11
# MyVariant.info API                          10
# BioThings UBERON API                         9
# Multiomics Wellness KP API                   9
# CTD API                                      8
# BioThings IDISK API                          7
# BioThings PFOCR API                          6
# BioThings GO Biological Process API          6
# BioThings DGIdb API                          6
# BioThings GO Molecular Function API          4
# BioThings MGIgene2phenotype API              4
# BioThings GO Cellular Component API          4
# Multiomics ClinicalTrials KP                 2
# BioThings BioPlanet Pathway-Gene API         2
# BioThings BioPlanet Pathway-Disease API      2
# BioThings BindingDB API                      2
# BioThings RARe-SOURCE API                    2
# BioThings HPO API                            2
# BioThings GTRx API                           2
# BioThings EBIgene2phenotype API              2
# BioThings DISEASES API                       2
# BioThings Rhea API                           2
# LitVar API                                   1
# EBI Proteins API                             1
# BioThings DDInter API                        1
# Ontology Lookup Service API                  1
# QuickGO API                                  1
# Name: api_name, dtype: int64

# %% [markdown]
# ## Summarization

# %% [markdown]
# ### by subject, object; count # of APIs

# %%
df1 = df_bte[["subject","object","api_name"]].drop_duplicates()
df1
# Out:
#                   subject             object  \
# 161530            Disease               Gene
# 161532            Disease            Pathway
# 161533            Disease  PhenotypicFeature
# 161534            Disease    SequenceVariant
# 161536               Gene            Disease
# ...                   ...                ...
# 161573  PhenotypicFeature               Gene
# 161567  PhenotypicFeature      SmallMolecule
# 161568      SmallMolecule            Disease
# 161554      SmallMolecule               Gene
# 161566      SmallMolecule  PhenotypicFeature
#
#                                     api_name
# 161530                           BioLink API
# 161532                           BioLink API
# 161533                           BioLink API
# 161534                           BioLink API
# 161536                           BioLink API
# ...                                      ...
# 161573  Text Mining Targeted Association API
# 161567  Text Mining Targeted Association API
# 161568  Text Mining Targeted Association API
# 161554  Text Mining Targeted Association API
# 161566  Text Mining Targeted Association API
#
# [326 rows x 3 columns]

# %%
api_stats = df1.groupby(['subject','object'], group_keys=False)['api_name'].nunique().rename("count").to_frame()
api_stats['list'] = df1.groupby(['subject','object'], group_keys=False)['api_name'].unique().apply(list)
api_stats = api_stats.reset_index().sort_values(by=['count'],ascending=False)

api_stats.head(15)
# Out:
#                subject             object  count  \
# 50             Disease               Gene     13
# 72                Gene            Disease     12
# 61             Disease      SmallMolecule      9
# 197      SmallMolecule               Gene      8
# 83                Gene      SmallMolecule      8
# 196      SmallMolecule            Disease      8
# 73                Gene               Gene      5
# 135  PhenotypicFeature      SmallMolecule      4
# 55             Disease  PhenotypicFeature      4
# 78                Gene  PhenotypicFeature      4
# 126  PhenotypicFeature            Disease      4
# 47             Disease            Disease      4
# 199      SmallMolecule  MolecularActivity      4
# 201      SmallMolecule  PhenotypicFeature      4
# 127  PhenotypicFeature               Gene      4
#
#                                                   list
# 50   [BioLink API, BioThings DISEASES API, BioThing...
# 72   [BioLink API, BioThings DISEASES API, BioThing...
# 61   [BioThings GTRx API, BioThings IDISK API, BioT...
# 197  [BioThings BindingDB API, BioThings DGIdb API,...
# 83   [BioThings BindingDB API, BioThings DGIdb API,...
# 196  [BioThings GTRx API, BioThings IDISK API, BioT...
# 73   [BioLink API, BioThings SEMMEDDB API, Multiomi...
# 135  [BioThings IDISK API, BioThings SEMMEDDB API, ...
# 55   [BioLink API, BioThings SEMMEDDB API, Multiomi...
# 78   [BioLink API, BioThings MGIgene2phenotype API,...
# 126  [BioLink API, BioThings SEMMEDDB API, Multiomi...
# 47   [BioThings SEMMEDDB API, Multiomics EHR Risk K...
# 199  [BioThings Rhea API, BioThings SEMMEDDB API, C...
# 201  [BioThings IDISK API, BioThings SEMMEDDB API, ...
# 127  [BioLink API, BioThings MGIgene2phenotype API,...

# %%
api_stats.to_csv("results/api_stats.tsv", sep="\t", index=False)

# %% [markdown]
# ### by subject, object; count # of predicates

# %%
df1 = df_bte[["subject","object","predicate"]].drop_duplicates()
predicate_stats = df1.groupby(['subject','object'], group_keys=False)['predicate'].nunique().rename("count").to_frame()
predicate_stats['list'] = df1.groupby(['subject','object'], group_keys=False)['predicate'].unique().apply(list)
predicate_stats = predicate_stats.reset_index().sort_values(by=['count'],ascending=False)

predicate_stats.head(15)
# Out:
#                  subject               object  count  \
# 47               Disease              Disease     26
# 53               Disease  PathologicalProcess     15
# 73                  Gene                 Gene     15
# 61               Disease        SmallMolecule     15
# 111  PathologicalProcess              Disease     15
# 196        SmallMolecule              Disease     15
# 50               Disease                 Gene     13
# 197        SmallMolecule                 Gene     13
# 72                  Gene              Disease     13
# 83                  Gene        SmallMolecule     13
# 206        SmallMolecule        SmallMolecule     11
# 116  PathologicalProcess  PathologicalProcess     11
# 154          Polypeptide              Disease     10
# 57               Disease          Polypeptide     10
# 161          Polypeptide          Polypeptide     10
#
#                                                   list
# 47   [affected_by, affects, caused_by, causes, coex...
# 53   [affected_by, affects, caused_by, causes, coex...
# 73   [interacts_with, affected_by, affects, coexist...
# 61   [treated_by, adverse_event_of, occurs_together...
# 111  [affected_by, affects, caused_by, causes, coex...
# 196  [treats, has_adverse_event, occurs_together_in...
# 50   [caused_by, condition_associated_with_gene, re...
# 197  [physically_interacts_with, affects, interacts...
# 72   [causes, gene_associated_with_condition, relat...
# 83   [physically_interacts_with, affected_by, inter...
# 206  [interacts_with, affected_by, affects, coexist...
# 116  [affected_by, affects, caused_by, causes, coex...
# 154  [affects, causes, disrupts, exacerbates, part_...
# 57   [affected_by, caused_by, disrupted_by, has_par...
# 161  [affected_by, affects, coexists_with, derives_...

# %%
predicate_stats.to_csv("results/predicate_stats.tsv", sep="\t", index=False)

# %% [markdown]
# ## Filter by most common types

# %% [markdown]
# Filter to only include the most common types of entities.  Also, since we _mostly_ have the same info in both directions, only keep one direction to simplify visualization

# %%
pd.concat([df_bte['subject'], df_bte['object']]).value_counts().head(20)
# Out:
# Disease                     325
# Gene                        256
# SmallMolecule               250
# Polypeptide                 182
# PathologicalProcess         174
# ChemicalEntity              132
# PhenotypicFeature           127
# PhysiologicalProcess        124
# Procedure                    80
# Cell                         72
# CellularComponent            71
# GrossAnatomicalStructure     70
# MolecularActivity            62
# Protein                      46
# AnatomicalEntity             18
# Drug                         16
# SequenceVariant              15
# BiologicalProcess            15
# Food                         14
# Pathway                       9
# dtype: int64

# %%
NUM_TYPES_TO_KEEP = 8

keep = set(pd.concat([df_bte['subject'], df_bte['object']]).value_counts().head(NUM_TYPES_TO_KEEP).keys())
keep
# Out:
# {'ChemicalEntity',
#  'Disease',
#  'Gene',
#  'PathologicalProcess',
#  'PhenotypicFeature',
#  'PhysiologicalProcess',
#  'Polypeptide',
#  'SmallMolecule'}

# %%
predicate_stats_filt = predicate_stats.query("subject in @keep & object in @keep & subject <= object").sort_values(by=['count'], ascending=False)
predicate_stats_filt.to_csv("results/predicate_stats_filt.tsv", sep="\t")
predicate_stats_filt
# Out:
#                   subject                object  count  \
# 47                Disease               Disease     26
# 73                   Gene                  Gene     15
# 61                Disease         SmallMolecule     15
# 53                Disease   PathologicalProcess     15
# 50                Disease                  Gene     13
# 83                   Gene         SmallMolecule     13
# 206         SmallMolecule         SmallMolecule     11
# 116   PathologicalProcess   PathologicalProcess     11
# 161           Polypeptide           Polypeptide     10
# 135     PhenotypicFeature         SmallMolecule     10
# 57                Disease           Polypeptide     10
# 164           Polypeptide         SmallMolecule      9
# 55                Disease     PhenotypicFeature      9
# 56                Disease  PhysiologicalProcess      9
# 122   PathologicalProcess         SmallMolecule      9
# 80                   Gene           Polypeptide      9
# 119   PathologicalProcess           Polypeptide      9
# 31         ChemicalEntity               Disease      8
# 146  PhysiologicalProcess  PhysiologicalProcess      7
# 38         ChemicalEntity           Polypeptide      7
# 78                   Gene     PhenotypicFeature      7
# 35         ChemicalEntity   PathologicalProcess      7
# 132     PhenotypicFeature           Polypeptide      7
# 130     PhenotypicFeature     PhenotypicFeature      7
# 32         ChemicalEntity                  Gene      7
# 76                   Gene   PathologicalProcess      6
# 150  PhysiologicalProcess         SmallMolecule      6
# 147  PhysiologicalProcess           Polypeptide      6
# 118   PathologicalProcess  PhysiologicalProcess      6
# 30         ChemicalEntity        ChemicalEntity      6
# 40         ChemicalEntity         SmallMolecule      5
# 37         ChemicalEntity  PhysiologicalProcess      4
# 117   PathologicalProcess     PhenotypicFeature      4
# 36         ChemicalEntity     PhenotypicFeature      4
# 79                   Gene  PhysiologicalProcess      4
# 131     PhenotypicFeature  PhysiologicalProcess      3
#
#                                                   list
# 47   [affected_by, affects, caused_by, causes, coex...
# 73   [interacts_with, affected_by, affects, coexist...
# 61   [treated_by, adverse_event_of, occurs_together...
# 53   [affected_by, affects, caused_by, causes, coex...
# 50   [caused_by, condition_associated_with_gene, re...
# 83   [physically_interacts_with, affected_by, inter...
# 206  [interacts_with, affected_by, affects, coexist...
# 116  [affected_by, affects, caused_by, causes, coex...
# 161  [affected_by, affects, coexists_with, derives_...
# 135  [adverse_event_of, affected_by, caused_by, dis...
# 57   [affected_by, caused_by, disrupted_by, has_par...
# 164  [affected_by, affects, coexists_with, derives_...
# 55   [has_phenotype, caused_by, causes, coexists_wi...
# 56   [affected_by, affects, causes, coexists_with, ...
# 122  [affected_by, caused_by, disrupted_by, has_pre...
# 80   [affected_by, affects, coexists_with, derives_...
# 119  [affected_by, caused_by, disrupted_by, has_pre...
# 31   [affects, causes, disrupts, predisposes, preve...
# 146  [affected_by, affects, caused_by, causes, coex...
# 38   [affected_by, affects, coexists_with, derives_...
# 78   [gene_associated_with_condition, related_to, a...
# 35   [affects, causes, disrupts, predisposes, preve...
# 132  [affected_by, caused_by, disrupted_by, has_pre...
# 130  [subclass_of, superclass_of, caused_by, causes...
# 32   [affected_by, affects, coexists_with, derives_...
# 76   [affects, causes, disrupts, predisposes, preve...
# 150  [affected_by, affects, caused_by, disrupted_by...
# 147  [affected_by, affects, caused_by, disrupted_by...
# 118  [affected_by, affects, causes, disrupts, manif...
# 30   [affected_by, affects, coexists_with, derives_...
# 40   [affected_by, affects, coexists_with, derives_...
# 37            [affects, causes, disrupts, produced_by]
# 117  [causes, coexists_with, has_manifestation, pre...
# 36          [affects, causes, predisposes, related_to]
# 79            [affected_by, affects, causes, disrupts]
# 131             [causes, manifestation_of, related_to]

# %%
api_stats_filt = api_stats.query("subject in @keep & object in @keep & subject <= object").sort_values(by=['count'], ascending=False)
api_stats_filt.to_csv("results/api_stats_filt.tsv", sep="\t")
api_stats_filt
# Out:
#                   subject                object  count  \
# 50                Disease                  Gene     13
# 61                Disease         SmallMolecule      9
# 83                   Gene         SmallMolecule      8
# 73                   Gene                  Gene      5
# 135     PhenotypicFeature         SmallMolecule      4
# 55                Disease     PhenotypicFeature      4
# 78                   Gene     PhenotypicFeature      4
# 47                Disease               Disease      4
# 206         SmallMolecule         SmallMolecule      4
# 130     PhenotypicFeature     PhenotypicFeature      3
# 40         ChemicalEntity         SmallMolecule      1
# 32         ChemicalEntity                  Gene      1
# 35         ChemicalEntity   PathologicalProcess      1
# 37         ChemicalEntity  PhysiologicalProcess      1
# 38         ChemicalEntity           Polypeptide      1
# 76                   Gene   PathologicalProcess      1
# 53                Disease   PathologicalProcess      1
# 56                Disease  PhysiologicalProcess      1
# 57                Disease           Polypeptide      1
# 30         ChemicalEntity        ChemicalEntity      1
# 79                   Gene  PhysiologicalProcess      1
# 31         ChemicalEntity               Disease      1
# 150  PhysiologicalProcess         SmallMolecule      1
# 36         ChemicalEntity     PhenotypicFeature      1
# 116   PathologicalProcess   PathologicalProcess      1
# 164           Polypeptide         SmallMolecule      1
# 161           Polypeptide           Polypeptide      1
# 132     PhenotypicFeature           Polypeptide      1
# 131     PhenotypicFeature  PhysiologicalProcess      1
# 147  PhysiologicalProcess           Polypeptide      1
# 117   PathologicalProcess     PhenotypicFeature      1
# 118   PathologicalProcess  PhysiologicalProcess      1
# 146  PhysiologicalProcess  PhysiologicalProcess      1
# 119   PathologicalProcess           Polypeptide      1
# 122   PathologicalProcess         SmallMolecule      1
# 80                   Gene           Polypeptide      1
#
#                                                   list
# 50   [BioLink API, BioThings DISEASES API, BioThing...
# 61   [BioThings GTRx API, BioThings IDISK API, BioT...
# 83   [BioThings BindingDB API, BioThings DGIdb API,...
# 73   [BioLink API, BioThings SEMMEDDB API, Multiomi...
# 135  [BioThings IDISK API, BioThings SEMMEDDB API, ...
# 55   [BioLink API, BioThings SEMMEDDB API, Multiomi...
# 78   [BioLink API, BioThings MGIgene2phenotype API,...
# 47   [BioThings SEMMEDDB API, Multiomics EHR Risk K...
# 206  [BioThings DDInter API, BioThings IDISK API, B...
# 130  [BioThings HPO API, BioThings SEMMEDDB API, Mu...
# 40                            [BioThings SEMMEDDB API]
# 32                            [BioThings SEMMEDDB API]
# 35                            [BioThings SEMMEDDB API]
# 37                            [BioThings SEMMEDDB API]
# 38                            [BioThings SEMMEDDB API]
# 76                            [BioThings SEMMEDDB API]
# 53                            [BioThings SEMMEDDB API]
# 56                            [BioThings SEMMEDDB API]
# 57                            [BioThings SEMMEDDB API]
# 30                            [BioThings SEMMEDDB API]
# 79                            [BioThings SEMMEDDB API]
# 31                            [BioThings SEMMEDDB API]
# 150                           [BioThings SEMMEDDB API]
# 36                            [BioThings SEMMEDDB API]
# 116                           [BioThings SEMMEDDB API]
# 164                           [BioThings SEMMEDDB API]
# 161                           [BioThings SEMMEDDB API]
# 132                           [BioThings SEMMEDDB API]
# 131                           [BioThings SEMMEDDB API]
# 147                           [BioThings SEMMEDDB API]
# 117                           [BioThings SEMMEDDB API]
# 118                           [BioThings SEMMEDDB API]
# 146                           [BioThings SEMMEDDB API]
# 119                           [BioThings SEMMEDDB API]
# 122                           [BioThings SEMMEDDB API]
# 80                            [BioThings SEMMEDDB API]

# %% [markdown]
# ## Export to graphml

# %%
def create_graph(df2, filename):
    G = nx.Graph()

    node_types = set(pd.concat([df2['subject'], df2['object']]))
        
    for node_type in node_types:
        G.add_node(node_type, label = add_spacing(node_type))

    for index,row in df2.iterrows():
        if 'count' in row.keys():
            G.add_edge(row['subject'], row['object'], weight=row['count'])
        else:
            G.add_edge(row['subject'], row['object'])
    
    nx.write_graphml(G, filename, infer_numeric_types=True)
    return(G)

# %%
def add_spacing(str):
    key = {
        "BiologicalProcess":               "Biological\nProcess",
        "ChemicalEntity":                  "Chemical\nEntity",
        "MolecularMixture":                "Molecular\nMixture", 
        "PhysiologicalProcess":            "Physiological\nProcess",
        "SmallMolecule":                   "Small\nMolecule",
        "PhenotypicFeature":               "Phenotypic\nFeature",
        'ChemicalExposure':                'Chemical\nExposure',
        'ClinicalAttribute':               'Clinical\nAttribute',
        'ClinicalIntervention':            'Clinical\nIntervention',
        'ComplexMolecularMixture':         'Complex\nMolecular\nMixture',
        'EnvironmentalExposure':           'Environmental\nExposure',
        'InformationContentEntity':        'Information\nContentEntity',
        'MolecularMixture':                'Molecular\nMixture',
        'PhysiologicalProcess':            'Physiological\nProcess',
        'PopulationOfIndividualOrganisms': 'PopulationOf\nIndividualOrganisms',
        'GrossAnatomicalStructure':        'Gross\nAnatomical\nStructure',
        'PathologicalProcess':             'Pathological\nProcess'
    }
    if str in key.keys():
        return(key[str])
    else:
        return(str)

# %%
g = create_graph(api_stats_filt, "results/api_stats_filt.graphml")
g = create_graph(predicate_stats_filt, "results/predicate_stats_filt.graphml")

# %%
g.edges
# Out:
# EdgeView([('Gene', 'Gene'), ('Gene', 'Disease'), ('Gene', 'SmallMolecule'), ('Gene', 'Polypeptide'), ('Gene', 'PhenotypicFeature'), ('Gene', 'ChemicalEntity'), ('Gene', 'PathologicalProcess'), ('Gene', 'PhysiologicalProcess'), ('Polypeptide', 'Polypeptide'), ('Polypeptide', 'Disease'), ('Polypeptide', 'SmallMolecule'), ('Polypeptide', 'PathologicalProcess'), ('Polypeptide', 'ChemicalEntity'), ('Polypeptide', 'PhenotypicFeature'), ('Polypeptide', 'PhysiologicalProcess'), ('SmallMolecule', 'Disease'), ('SmallMolecule', 'SmallMolecule'), ('SmallMolecule', 'PhenotypicFeature'), ('SmallMolecule', 'PathologicalProcess'), ('SmallMolecule', 'PhysiologicalProcess'), ('SmallMolecule', 'ChemicalEntity'), ('PhysiologicalProcess', 'Disease'), ('PhysiologicalProcess', 'PhysiologicalProcess'), ('PhysiologicalProcess', 'PathologicalProcess'), ('PhysiologicalProcess', 'ChemicalEntity'), ('PhysiologicalProcess', 'PhenotypicFeature'), ('PhenotypicFeature', 'Disease'), ('PhenotypicFeature', 'PhenotypicFeature'), ('PhenotypicFeature', 'PathologicalProcess'), ('PhenotypicFeature', 'ChemicalEntity'), ('Disease', 'Disease'), ('Disease', 'PathologicalProcess'), ('Disease', 'ChemicalEntity'), ('PathologicalProcess', 'PathologicalProcess'), ('PathologicalProcess', 'ChemicalEntity'), ('ChemicalEntity', 'ChemicalEntity')])

# %%
G = nx.Graph()
G.all_simple_paths(g, source="ChemicalEntity", target="Disease")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[25], line 2
#       1 G = nx.Graph()
# ----> 2 G.all_simple_paths(g, source="ChemicalEntity", target="Disease")
#
# AttributeError: 'Graph' object has no attribute 'all_simple_paths'

# %% [markdown]
# ## Restricted subway diagram
#
# Ultimately wasn't able to get a usable figure out of this, but keeping this section in case I want to experiment with this again later.

# %%
NUM_TYPES_TO_KEEP = 5

keep = set(pd.concat([df_bte['subject'], df_bte['object']]).value_counts().head(NUM_TYPES_TO_KEEP).keys())
keep

# %%
df_subway = df_bte.query('object in @keep & subject in @keep & subject < object').drop(columns=['predicate']).drop_duplicates()
df_subway

# %%
G = nx.MultiGraph()

df2 = df_subway

node_types = set(pd.concat([df2['subject'], df2['object']]))
        
for node_type in node_types:
    G.add_node(node_type, label = add_spacing(node_type))

# %%
idcount = 0
for index,row in df2.iterrows():
    G.add_edge(row['subject'], row['object'], api_name=row['api_name'], key=idcount)
    idcount = idcount + 1

# %%
nx.write_graphml(G, "results/subway.graphml", infer_numeric_types=True,named_key_ids=True)

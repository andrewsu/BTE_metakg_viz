# %% [markdown]
# # BTE metakg visualization
#
# The goal of this notebook is to visualize the metaKG that BTE uses.  Similar to the [subway diagram](https://raw.githubusercontent.com/biothings/BioThings_Explorer_TRAPI/main/diagrams/smartapi_metagraph.png) we've used before, but updated to the size and scale of the current metakg.
#
# Optimizations
# * remove less-commonly-used node types from subject/object
# * only count in one direction (`A-treats-B` gets merged with `B-treated_by-A`)

# %%
import biothings_client
import json5
import networkx as nx
import pandas as pd
import re
import requests

# %% [markdown]
# ## Read in SmartAPI data

# %% [markdown]
# ### Option 1 -- Read in the Smart API ndjson file

# %%
# older input file from Chunlei
#df = pd.read_json('data/smartapi_metakg_20230413.ndjson.gz', lines=True)

# newer input file from Chunlei -- preprocessed using following command:
#      gzip -cd smartapi_metakg_20230413.ndjson.gz | jq -c ' ._source' | gzip > smartapi_metakg_20230413b.ndjson.gz
df = pd.read_json('data/smartapi_metakg_20230413b.ndjson.gz', lines=True)
df
# Out:
#                      subject            object               predicate  \
# 0                    Disease           Disease           superclass_of
# 1            SequenceVariant              Gene  is_sequence_variant_of
# 2          GeneOrGeneProduct    ChemicalEntity                has_part
# 3          NucleicAcidEntity    ChemicalEntity                has_part
# 4             ChemicalEntity    ChemicalEntity                has_part
# ...                      ...               ...                     ...
# 367201    GeographicLocation         Procedure            derives_from
# 367202  ClinicalIntervention          Activity              related_to
# 367203           Polypeptide  AnatomicalEntity           coexists_with
# 367204            NamedThing        Phenomenon                has_part
# 367205                 Agent             Agent                  treats
#
#                      provided_by  \
# 0       infores:disease-ontology
# 1                  infores:dbsnp
# 2                            NaN
# 3                            NaN
# 4                            NaN
# ...                          ...
# 367201                       NaN
# 367202                       NaN
# 367203                       NaN
# 367204                       NaN
# 367205                       NaN
#
#                                                       api  \
# 0       {'name': 'Ontology Lookup Service API', 'smart...
# 1       {'name': 'LitVar API', 'smartapi': {'metadata'...
# 2       {'name': 'Ontology-KP API', 'smartapi': {'meta...
# 3       {'name': 'Ontology-KP API', 'smartapi': {'meta...
# 4       {'name': 'Ontology-KP API', 'smartapi': {'meta...
# ...                                                   ...
# 367201  {'name': 'ARAX Translator Reasoner - TRAPI 1.3...
# 367202  {'name': 'ARAX Translator Reasoner - TRAPI 1.3...
# 367203  {'name': 'ARAX Translator Reasoner - TRAPI 1.3...
# 367204  {'name': 'ARAX Translator Reasoner - TRAPI 1.3...
# 367205  {'name': 'ARAX Translator Reasoner - TRAPI 1.3...
#
#                                                       bte
# 0       {'query_operation': {'params': {'id': '{{ quer...
# 1       {'query_operation': {'params': {'variantid': '...
# 2       {'query_operation': {'path': '/query', 'method...
# 3       {'query_operation': {'path': '/query', 'method...
# 4       {'query_operation': {'path': '/query', 'method...
# ...                                                   ...
# 367201  {'query_operation': {'path': '/query', 'method...
# 367202  {'query_operation': {'path': '/query', 'method...
# 367203  {'query_operation': {'path': '/query', 'method...
# 367204  {'query_operation': {'path': '/query', 'method...
# 367205  {'query_operation': {'path': '/query', 'method...
#
# [367206 rows x 6 columns]

# %% [markdown]
# ### Option 2 (preferred) -- Query the SmartAPI API
#
# This method takes longer, but it retrieves the most up-to-date data

# %%
c = biothings_client.get_client('metakg', url='https://smart-api.info/api/metakg')
c._query_endpoint=''
a = c.query('*', fetch_all=True)

# %%
df = pd.DataFrame(a)
df
# Out:
# Fetching 338605 metakg(s) . . .
# No more results to return.
#                          _id  _score  \
# 0       1m-wcYcBXoKXcforQySO     1.0
# 1       12-wcYcBXoKXcforQySO     1.0
# 2       2G-wcYcBXoKXcforQySO     1.0
# 3       2W-wcYcBXoKXcforQySO     1.0
# 4       2m-wcYcBXoKXcforQySO     1.0
# ...                      ...     ...
# 338600  anO0cYcBXoKXcforsf-o     1.0
# 338601  a3O0cYcBXoKXcforsf-o     1.0
# 338602  bHO0cYcBXoKXcforsf-o     1.0
# 338603  bXO0cYcBXoKXcforsf-o     1.0
# 338604  bnO0cYcBXoKXcforsf-o     1.0
#
#                                                       api  \
# 0       {'name': 'CAM-KP API', 'smartapi': {'id': '642...
# 1       {'name': 'CAM-KP API', 'smartapi': {'id': '642...
# 2       {'name': 'CAM-KP API', 'smartapi': {'id': '642...
# 3       {'name': 'CAM-KP API', 'smartapi': {'id': '642...
# 4       {'name': 'CAM-KP API', 'smartapi': {'id': '642...
# ...                                                   ...
# 338600  {'name': 'ARAX Translator Reasoner - TRAPI 1.3...
# 338601  {'name': 'ARAX Translator Reasoner - TRAPI 1.3...
# 338602  {'name': 'ARAX Translator Reasoner - TRAPI 1.3...
# 338603  {'name': 'ARAX Translator Reasoner - TRAPI 1.3...
# 338604  {'name': 'ARAX Translator Reasoner - TRAPI 1.3...
#
#                                                       bte  \
# 0       {'query_operation': {'input_separator': ',', '...
# 1       {'query_operation': {'input_separator': ',', '...
# 2       {'query_operation': {'input_separator': ',', '...
# 3       {'query_operation': {'input_separator': ',', '...
# 4       {'query_operation': {'input_separator': ',', '...
# ...                                                   ...
# 338600  {'query_operation': {'input_separator': ',', '...
# 338601  {'query_operation': {'input_separator': ',', '...
# 338602  {'query_operation': {'input_separator': ',', '...
# 338603  {'query_operation': {'input_separator': ',', '...
# 338604  {'query_operation': {'input_separator': ',', '...
#
#                             object                         predicate  \
# 0       MacromolecularMachineMixin                  acts_upstream_of
# 1                MolecularActivity                  acts_upstream_of
# 2                       NamedThing                  acts_upstream_of
# 3                 BiologicalEntity  acts_upstream_of_negative_effect
# 4                BiologicalProcess  acts_upstream_of_negative_effect
# ...                            ...                               ...
# 338600                   Procedure                      derives_from
# 338601                    Activity                        related_to
# 338602            AnatomicalEntity                     coexists_with
# 338603                  Phenomenon                          has_part
# 338604                       Agent                            treats
#
#                      subject provided_by
# 0              GenomicEntity         NaN
# 1              GenomicEntity         NaN
# 2              GenomicEntity         NaN
# 3              GenomicEntity         NaN
# 4              GenomicEntity         NaN
# ...                      ...         ...
# 338600    GeographicLocation         NaN
# 338601  ClinicalIntervention         NaN
# 338602           Polypeptide         NaN
# 338603            NamedThing         NaN
# 338604                 Agent         NaN
#
# [338605 rows x 8 columns]

# %% [markdown]
# ### Post-processing

# %% [markdown]
# parse out a couple lines for the API name and ID

# %%
df = df.assign(api_name = lambda x: pd.json_normalize(x['api'])['name'])
df = df.assign(api_id = lambda x: pd.json_normalize(x['api'])['smartapi.id'])
df
# Out:
#                          _id  _score  \
# 0       1m-wcYcBXoKXcforQySO     1.0
# 1       12-wcYcBXoKXcforQySO     1.0
# 2       2G-wcYcBXoKXcforQySO     1.0
# 3       2W-wcYcBXoKXcforQySO     1.0
# 4       2m-wcYcBXoKXcforQySO     1.0
# ...                      ...     ...
# 338600  anO0cYcBXoKXcforsf-o     1.0
# 338601  a3O0cYcBXoKXcforsf-o     1.0
# 338602  bHO0cYcBXoKXcforsf-o     1.0
# 338603  bXO0cYcBXoKXcforsf-o     1.0
# 338604  bnO0cYcBXoKXcforsf-o     1.0
#
#                                                       api  \
# 0       {'name': 'CAM-KP API', 'smartapi': {'id': '642...
# 1       {'name': 'CAM-KP API', 'smartapi': {'id': '642...
# 2       {'name': 'CAM-KP API', 'smartapi': {'id': '642...
# 3       {'name': 'CAM-KP API', 'smartapi': {'id': '642...
# 4       {'name': 'CAM-KP API', 'smartapi': {'id': '642...
# ...                                                   ...
# 338600  {'name': 'ARAX Translator Reasoner - TRAPI 1.3...
# 338601  {'name': 'ARAX Translator Reasoner - TRAPI 1.3...
# 338602  {'name': 'ARAX Translator Reasoner - TRAPI 1.3...
# 338603  {'name': 'ARAX Translator Reasoner - TRAPI 1.3...
# 338604  {'name': 'ARAX Translator Reasoner - TRAPI 1.3...
#
#                                                       bte  \
# 0       {'query_operation': {'input_separator': ',', '...
# 1       {'query_operation': {'input_separator': ',', '...
# 2       {'query_operation': {'input_separator': ',', '...
# 3       {'query_operation': {'input_separator': ',', '...
# 4       {'query_operation': {'input_separator': ',', '...
# ...                                                   ...
# 338600  {'query_operation': {'input_separator': ',', '...
# 338601  {'query_operation': {'input_separator': ',', '...
# 338602  {'query_operation': {'input_separator': ',', '...
# 338603  {'query_operation': {'input_separator': ',', '...
# 338604  {'query_operation': {'input_separator': ',', '...
#
#                             object                         predicate  \
# 0       MacromolecularMachineMixin                  acts_upstream_of
# 1                MolecularActivity                  acts_upstream_of
# 2                       NamedThing                  acts_upstream_of
# 3                 BiologicalEntity  acts_upstream_of_negative_effect
# 4                BiologicalProcess  acts_upstream_of_negative_effect
# ...                            ...                               ...
# 338600                   Procedure                      derives_from
# 338601                    Activity                        related_to
# 338602            AnatomicalEntity                     coexists_with
# 338603                  Phenomenon                          has_part
# 338604                       Agent                            treats
#
#                      subject provided_by  \
# 0              GenomicEntity         NaN
# 1              GenomicEntity         NaN
# 2              GenomicEntity         NaN
# 3              GenomicEntity         NaN
# 4              GenomicEntity         NaN
# ...                      ...         ...
# 338600    GeographicLocation         NaN
# 338601  ClinicalIntervention         NaN
# 338602           Polypeptide         NaN
# 338603            NamedThing         NaN
# 338604                 Agent         NaN
#
#                                       api_name  \
# 0                                   CAM-KP API
# 1                                   CAM-KP API
# 2                                   CAM-KP API
# 3                                   CAM-KP API
# 4                                   CAM-KP API
# ...                                        ...
# 338600  ARAX Translator Reasoner - TRAPI 1.3.0
# 338601  ARAX Translator Reasoner - TRAPI 1.3.0
# 338602  ARAX Translator Reasoner - TRAPI 1.3.0
# 338603  ARAX Translator Reasoner - TRAPI 1.3.0
# 338604  ARAX Translator Reasoner - TRAPI 1.3.0
#
#                                   api_id
# 0       642b1dbcd0943f3a119d714cf7535fba
# 1       642b1dbcd0943f3a119d714cf7535fba
# 2       642b1dbcd0943f3a119d714cf7535fba
# 3       642b1dbcd0943f3a119d714cf7535fba
# 4       642b1dbcd0943f3a119d714cf7535fba
# ...                                  ...
# 338600  e248aefca0f469229e82cca80fbabc89
# 338601  e248aefca0f469229e82cca80fbabc89
# 338602  e248aefca0f469229e82cca80fbabc89
# 338603  e248aefca0f469229e82cca80fbabc89
# 338604  e248aefca0f469229e82cca80fbabc89
#
# [338605 rows x 10 columns]

# %% [markdown]
# ## Read in the BTE config file that specifies currently-allowed APIs

# %%
bte_config_url = "https://raw.githubusercontent.com/biothings/BioThings_Explorer_TRAPI/main/src/config/apis.js"
r = requests.get(bte_config_url)
str_bte_config = r.text
#print(str_bte_config)
str_bte_config = re.sub("exports.API_LIST = ",  "", str_bte_config)                       # remove variable assignment step
str_bte_config = re.sub("\s*//.*",              "", str_bte_config)                       # remove commented lines
str_bte_config = re.sub(r'^$\n',                '', str_bte_config, flags=re.MULTILINE)   # remove blank lines
str_bte_config = re.sub(r',\s*exclude:[^\]]*]', '', str_bte_config, flags=re.MULTILINE)   # remove 'exclude' section
str_bte_config = re.sub(r';$',                  '', str_bte_config, flags=re.MULTILINE)   # remove 'exclude' section
#print(str_bte_config)

bte_config = json5.loads(str_bte_config)['include']
bte_config
# Out:
# [{'id': 'd22b657426375a5295e7da8a303b9893', 'name': 'BioLink API'},
#  {'id': '0212611d1c670f9107baf00b77f0889a',
#   'name': 'CTD API',
#   'primarySource': True},
#  {'id': '43af91b3d7cae43591083bff9d75c6dd', 'name': 'EBI Proteins API'},
#  {'id': 'dca415f2d792976af9d642b7e73f7a41', 'name': 'LitVar API'},
#  {'id': '1f277e1563fcfd124bfae2cc3c4bcdec', 'name': 'QuickGO API'},
#  {'id': '1c056ffc7ed0dd1229e71c4752239465',
#   'name': 'Ontology Lookup Service API'},
#  {'id': '38e9e5169a72aee3659c9ddba956790d', 'name': 'BioThings BindingDB API'},
#  {'id': '55a223c6c6e0291dbd05f2faf27d16f4',
#   'name': 'BioThings BioPlanet Pathway-Disease API'},
#  {'id': 'b99c6dd64abcefe87dcd0a51c249ee6d',
#   'name': 'BioThings BioPlanet Pathway-Gene API'},
#  {'id': '00fb85fc776279163199e6c50f6ddfc6', 'name': 'BioThings DDInter API'},
#  {'id': 'e3edd325c76f2992a111b43a907a4870', 'name': 'BioThings DGIdb API'},
#  {'id': 'a7f784626a426d054885a5f33f17d3f8', 'name': 'BioThings DISEASES API'},
#  {'id': '1f47552dabd67351d4c625adb0a10d00',
#   'name': 'BioThings EBIgene2phenotype API'},
#  {'id': 'cc857d5b7c8b7609b5bbb38ff990bfff',
#   'name': 'BioThings GO Biological Process API'},
#  {'id': 'f339b28426e7bf72028f60feefcd7465',
#   'name': 'BioThings GO Cellular Component API'},
#  {'id': '34bad236d77bea0a0ee6c6cba5be54a6',
#   'name': 'BioThings GO Molecular Function API'},
#  {'id': '316eab811fd9ef1097df98bcaa9f7361', 'name': 'BioThings GTRx API'},
#  {'id': 'a5b0ec6bfde5008984d4b6cde402d61f', 'name': 'BioThings HPO API'},
#  {'id': '32f36164fabed5d3abe6c2fd899c9418', 'name': 'BioThings IDISK API'},
#  {'id': '77ed27f111262d0289ed4f4071faa619',
#   'name': 'BioThings MGIgene2phenotype API'},
#  {'id': 'edeb26858bd27d0322af93e7a9e08761', 'name': 'BioThings PFOCR API'},
#  {'id': '03283cc2b21c077be6794e1704b1d230', 'name': 'BioThings Rhea API'},
#  {'id': '1d288b3a3caf75d541ffaae3aab386c8', 'name': 'BioThings SEMMEDDB API'},
#  {'id': 'ec6d76016ef40f284359d17fbf78df20', 'name': 'BioThings UBERON API'},
#  {'id': '8f08d1446e0bb9c2b323713ce83e2bd3', 'name': 'MyChem.info API'},
#  {'id': '671b45c0301c8624abbd26ae78449ca2', 'name': 'MyDisease.info API'},
#  {'id': '59dce17363dce279d389100834e43648', 'name': 'MyGene.info API'},
#  {'id': '09c8782d9f4027712e65b95424adba79', 'name': 'MyVariant.info API'},
#  {'id': 'adf20dd6ff23dfe18e8e012bde686e31',
#   'name': 'Multiomics BigGIM-DrugResponse KP API'},
#  {'id': '08a5ddcde71b4bf838327ef469076acd',
#   'name': 'Multiomics ClinicalTrials KP'},
#  {'id': 'd86a24f6027ffe778f84ba10a7a1861a',
#   'name': 'Multiomics EHR Risk KP API',
#   'primarySource': True},
#  {'id': '02af7d098ab304e80d6f4806c3527027',
#   'name': 'Multiomics Wellness KP API',
#   'primarySource': True},
#  {'id': '978fe380a147a8641caf72320862697b',
#   'name': 'Text Mining Targeted Association API'},
#  {'id': '25085b05fd1afcebb497724d147cfb44',
#   'name': 'Automat-biolink(Trapi v1.3.0)'},
#  {'id': '89aa98098ba4329aa49b43ff8d21ffbb',
#   'name': 'Automat-ctd(Trapi v1.3.0)'},
#  {'id': '463525b319d7e1ef8f705bce953d01bd',
#   'name': 'Automat-cord19(Trapi v1.3.0)'},
#  {'id': '539873b1f2f2eb913efaee411e09eaa7',
#   'name': 'Automat-drug-central(Trapi v1.3.0)'},
#  {'id': '272c2357763e4faf737f1cba94beaa1d',
#   'name': 'Automat-gtex(Trapi v1.3.0)'},
#  {'id': 'fb1f3780ad67b030cb0617363afa8f61',
#   'name': 'Automat-gwas-catalog(Trapi v1.3.0)'},
#  {'id': 'aacdd9e863bb659574d302f084084976',
#   'name': 'Automat-gtopdb(Trapi v1.3.0)'},
#  {'id': '7382f0fabffce3cc7f7b8b6358c69259',
#   'name': 'Automat-hgnc(Trapi v1.3.0)'},
#  {'id': 'ee2d2eae42ca30fe82946d3f42febaa0',
#   'name': 'Automat-hmdb(Trapi v1.3.0)'},
#  {'id': '830600da121a5accc955cbf62e60f802',
#   'name': 'Automat-hetio(Trapi v1.3.0)'},
#  {'id': 'f30339a6894a146a19a34974712ca2e3',
#   'name': 'Automat-human-goa(Trapi v1.3.0)'},
#  {'id': '44e7a1147ca8657f50af6bb25982762d',
#   'name': 'Automat-icees-kg(Trapi v1.3.0)'},
#  {'id': 'e0687431a9ff88344d20e83e0c99ee7d',
#   'name': 'Automat-intact(Trapi v1.3.0)'},
#  {'id': '4c6f9117581531161849e60ea906f0be',
#   'name': 'Automat-ontology-hierarchy(Trapi v1.3.0)'},
#  {'id': '2a879882329b000c7e7f08c2d71ccffd',
#   'name': 'Automat-panther(Trapi v1.3.0)'},
#  {'id': '0295640b4d060133e4296dda4c31da47',
#   'name': 'Automat-pharos(Trapi v1.3.0)'},
#  {'id': 'ef9027a7d2246c6540cc7b3ce202d89f',
#   'name': 'Automat-uberongraph(Trapi v1.3.0)'},
#  {'id': '79310edd01cae96f3d8495250e625886',
#   'name': 'Automat-viral-proteome(Trapi v1.3.0)'},
#  {'id': '51c178099fa2dc99b5d8fff8bf9f1a0d', 'name': 'COHD TRAPI 1.3'},
#  {'id': '855adaa128ce5aa58a091d99e520d396',
#   'name': 'Connections Hypothesis Provider API'}]

# %%
bte_config_notrapi = [ item for item in bte_config if not re.search("trapi", item['name'], re.IGNORECASE)]

# temporary hack on next line pending merge of https://github.com/biothings/biothings_explorer/pull/624
bte_config_notrapi = [ item for item in bte_config_notrapi if item['name'] != "Connections Hypothesis Provider API" ]

bte_config_notrapi
# Out:
# [{'id': 'd22b657426375a5295e7da8a303b9893', 'name': 'BioLink API'},
#  {'id': '0212611d1c670f9107baf00b77f0889a',
#   'name': 'CTD API',
#   'primarySource': True},
#  {'id': '43af91b3d7cae43591083bff9d75c6dd', 'name': 'EBI Proteins API'},
#  {'id': 'dca415f2d792976af9d642b7e73f7a41', 'name': 'LitVar API'},
#  {'id': '1f277e1563fcfd124bfae2cc3c4bcdec', 'name': 'QuickGO API'},
#  {'id': '1c056ffc7ed0dd1229e71c4752239465',
#   'name': 'Ontology Lookup Service API'},
#  {'id': '38e9e5169a72aee3659c9ddba956790d', 'name': 'BioThings BindingDB API'},
#  {'id': '55a223c6c6e0291dbd05f2faf27d16f4',
#   'name': 'BioThings BioPlanet Pathway-Disease API'},
#  {'id': 'b99c6dd64abcefe87dcd0a51c249ee6d',
#   'name': 'BioThings BioPlanet Pathway-Gene API'},
#  {'id': '00fb85fc776279163199e6c50f6ddfc6', 'name': 'BioThings DDInter API'},
#  {'id': 'e3edd325c76f2992a111b43a907a4870', 'name': 'BioThings DGIdb API'},
#  {'id': 'a7f784626a426d054885a5f33f17d3f8', 'name': 'BioThings DISEASES API'},
#  {'id': '1f47552dabd67351d4c625adb0a10d00',
#   'name': 'BioThings EBIgene2phenotype API'},
#  {'id': 'cc857d5b7c8b7609b5bbb38ff990bfff',
#   'name': 'BioThings GO Biological Process API'},
#  {'id': 'f339b28426e7bf72028f60feefcd7465',
#   'name': 'BioThings GO Cellular Component API'},
#  {'id': '34bad236d77bea0a0ee6c6cba5be54a6',
#   'name': 'BioThings GO Molecular Function API'},
#  {'id': '316eab811fd9ef1097df98bcaa9f7361', 'name': 'BioThings GTRx API'},
#  {'id': 'a5b0ec6bfde5008984d4b6cde402d61f', 'name': 'BioThings HPO API'},
#  {'id': '32f36164fabed5d3abe6c2fd899c9418', 'name': 'BioThings IDISK API'},
#  {'id': '77ed27f111262d0289ed4f4071faa619',
#   'name': 'BioThings MGIgene2phenotype API'},
#  {'id': 'edeb26858bd27d0322af93e7a9e08761', 'name': 'BioThings PFOCR API'},
#  {'id': '03283cc2b21c077be6794e1704b1d230', 'name': 'BioThings Rhea API'},
#  {'id': '1d288b3a3caf75d541ffaae3aab386c8', 'name': 'BioThings SEMMEDDB API'},
#  {'id': 'ec6d76016ef40f284359d17fbf78df20', 'name': 'BioThings UBERON API'},
#  {'id': '8f08d1446e0bb9c2b323713ce83e2bd3', 'name': 'MyChem.info API'},
#  {'id': '671b45c0301c8624abbd26ae78449ca2', 'name': 'MyDisease.info API'},
#  {'id': '59dce17363dce279d389100834e43648', 'name': 'MyGene.info API'},
#  {'id': '09c8782d9f4027712e65b95424adba79', 'name': 'MyVariant.info API'},
#  {'id': 'adf20dd6ff23dfe18e8e012bde686e31',
#   'name': 'Multiomics BigGIM-DrugResponse KP API'},
#  {'id': '08a5ddcde71b4bf838327ef469076acd',
#   'name': 'Multiomics ClinicalTrials KP'},
#  {'id': 'd86a24f6027ffe778f84ba10a7a1861a',
#   'name': 'Multiomics EHR Risk KP API',
#   'primarySource': True},
#  {'id': '02af7d098ab304e80d6f4806c3527027',
#   'name': 'Multiomics Wellness KP API',
#   'primarySource': True},
#  {'id': '978fe380a147a8641caf72320862697b',
#   'name': 'Text Mining Targeted Association API'}]

# %%
# uncomment one of the following two lines to look at all APIs, or just x-bte APIs
#bte_config_ids = [ x['id'] for x in bte_config ]
bte_config_ids = [ x['id'] for x in bte_config_notrapi ]

print(len(bte_config_ids))
print(bte_config_ids)
# Out:
# 33
# ['d22b657426375a5295e7da8a303b9893', '0212611d1c670f9107baf00b77f0889a', '43af91b3d7cae43591083bff9d75c6dd', 'dca415f2d792976af9d642b7e73f7a41', '1f277e1563fcfd124bfae2cc3c4bcdec', '1c056ffc7ed0dd1229e71c4752239465', '38e9e5169a72aee3659c9ddba956790d', '55a223c6c6e0291dbd05f2faf27d16f4', 'b99c6dd64abcefe87dcd0a51c249ee6d', '00fb85fc776279163199e6c50f6ddfc6', 'e3edd325c76f2992a111b43a907a4870', 'a7f784626a426d054885a5f33f17d3f8', '1f47552dabd67351d4c625adb0a10d00', 'cc857d5b7c8b7609b5bbb38ff990bfff', 'f339b28426e7bf72028f60feefcd7465', '34bad236d77bea0a0ee6c6cba5be54a6', '316eab811fd9ef1097df98bcaa9f7361', 'a5b0ec6bfde5008984d4b6cde402d61f', '32f36164fabed5d3abe6c2fd899c9418', '77ed27f111262d0289ed4f4071faa619', 'edeb26858bd27d0322af93e7a9e08761', '03283cc2b21c077be6794e1704b1d230', '1d288b3a3caf75d541ffaae3aab386c8', 'ec6d76016ef40f284359d17fbf78df20', '8f08d1446e0bb9c2b323713ce83e2bd3', '671b45c0301c8624abbd26ae78449ca2', '59dce17363dce279d389100834e43648', '09c8782d9f4027712e65b95424adba79', 'adf20dd6ff23dfe18e8e012bde686e31', '08a5ddcde71b4bf838327ef469076acd', 'd86a24f6027ffe778f84ba10a7a1861a', '02af7d098ab304e80d6f4806c3527027', '978fe380a147a8641caf72320862697b']

# %% [markdown]
# ## Join SmartAPI data with BTE config IDs

# %%
df_bte = df.query('api_id in @bte_config_ids')[['subject','object','predicate','api_name','api_id']].drop_duplicates()
df_bte
# Out:
#                   subject             object          predicate  \
# 17393       SmallMolecule               Gene         related_to
# 17394                Gene      SmallMolecule         related_to
# 17395             Disease      SmallMolecule         related_to
# 17397       SmallMolecule  BiologicalProcess         related_to
# 17398       SmallMolecule  CellularComponent         related_to
# ...                   ...                ...                ...
# 293770            Disease      SmallMolecule  contribution_from
# 293773               Gene            Disease            affects
# 293774            Disease               Gene        affected_by
# 293775               Gene  PhenotypicFeature            affects
# 293776  PhenotypicFeature               Gene        affected_by
#
#                                     api_name                            api_id
# 17393                                CTD API  0212611d1c670f9107baf00b77f0889a
# 17394                                CTD API  0212611d1c670f9107baf00b77f0889a
# 17395                                CTD API  0212611d1c670f9107baf00b77f0889a
# 17397                                CTD API  0212611d1c670f9107baf00b77f0889a
# 17398                                CTD API  0212611d1c670f9107baf00b77f0889a
# ...                                      ...                               ...
# 293770  Text Mining Targeted Association API  978fe380a147a8641caf72320862697b
# 293773  Text Mining Targeted Association API  978fe380a147a8641caf72320862697b
# 293774  Text Mining Targeted Association API  978fe380a147a8641caf72320862697b
# 293775  Text Mining Targeted Association API  978fe380a147a8641caf72320862697b
# 293776  Text Mining Targeted Association API  978fe380a147a8641caf72320862697b
#
# [1041 rows x 5 columns]

# %%
df_bte.to_csv("results/bte_operations.tsv", sep="\t", index=False)

# %%
df_bte['api_name'].value_counts()
# Out:
# BioThings SEMMEDDB API                     826
# BioLink API                                 21
# Text Mining Targeted Association API        20
# MyDisease.info API                          17
# Multiomics Wellness KP API                  17
# Multiomics BigGIM-DrugResponse KP API       14
# Multiomics EHR Risk KP API                  14
# MyChem.info API                             12
# MyGene.info API                             11
# MyVariant.info API                          10
# BioThings UBERON API                         9
# CTD API                                      8
# BioThings IDISK API                          7
# BioThings GO Biological Process API          6
# BioThings PFOCR API                          6
# BioThings DGIdb API                          6
# BioThings GO Cellular Component API          4
# BioThings MGIgene2phenotype API              4
# BioThings GO Molecular Function API          4
# BioThings EBIgene2phenotype API              4
# BioThings HPO API                            2
# BioThings Rhea API                           2
# BioThings GTRx API                           2
# BioThings BioPlanet Pathway-Disease API      2
# BioThings BindingDB API                      2
# BioThings BioPlanet Pathway-Gene API         2
# Multiomics ClinicalTrials KP                 2
# BioThings DISEASES API                       2
# LitVar API                                   1
# EBI Proteins API                             1
# Ontology Lookup Service API                  1
# QuickGO API                                  1
# BioThings DDInter API                        1
# Name: api_name, dtype: int64

# %% [markdown]
# ## Summarization

# %% [markdown]
# ### by subject, object; count # of APIs

# %%
df1 = df_bte[["subject","object","api_name"]].drop_duplicates()
df1
# Out:
#                   subject             object  \
# 17393       SmallMolecule               Gene
# 17394                Gene      SmallMolecule
# 17395             Disease      SmallMolecule
# 17397       SmallMolecule  BiologicalProcess
# 17398       SmallMolecule  CellularComponent
# ...                   ...                ...
# 293757               Gene               Gene
# 293761               Gene            Disease
# 293762            Disease               Gene
# 293763               Gene  PhenotypicFeature
# 293764  PhenotypicFeature               Gene
#
#                                     api_name
# 17393                                CTD API
# 17394                                CTD API
# 17395                                CTD API
# 17397                                CTD API
# 17398                                CTD API
# ...                                      ...
# 293757  Text Mining Targeted Association API
# 293761  Text Mining Targeted Association API
# 293762  Text Mining Targeted Association API
# 293763  Text Mining Targeted Association API
# 293764  Text Mining Targeted Association API
#
# [326 rows x 3 columns]

# %%
api_stats = df1.groupby(['subject','object'], group_keys=False)['api_name'].nunique().rename("count").to_frame()
api_stats['list'] = df1.groupby(['subject','object'], group_keys=False)['api_name'].unique().apply(list)
api_stats = api_stats.reset_index().sort_values(by=['count'],ascending=False)

api_stats.head(15)
# Out:
#                subject             object  count  \
# 50             Disease               Gene     12
# 73                Gene            Disease     11
# 196      SmallMolecule               Gene      9
# 84                Gene      SmallMolecule      9
# 61             Disease      SmallMolecule      9
# 195      SmallMolecule            Disease      8
# 74                Gene               Gene      6
# 79                Gene  PhenotypicFeature      5
# 128  PhenotypicFeature               Gene      5
# 136  PhenotypicFeature      SmallMolecule      4
# 127  PhenotypicFeature            Disease      4
# 198      SmallMolecule  MolecularActivity      4
# 47             Disease            Disease      4
# 200      SmallMolecule  PhenotypicFeature      4
# 55             Disease  PhenotypicFeature      4
#
#                                                   list
# 50   [CTD API, MyDisease.info API, MyVariant.info A...
# 73   [MyDisease.info API, MyVariant.info API, MyGen...
# 196  [CTD API, MyChem.info API, BioThings BindingDB...
# 84   [CTD API, MyChem.info API, BioThings BindingDB...
# 61   [CTD API, MyDisease.info API, MyChem.info API,...
# 195  [MyDisease.info API, MyChem.info API, BioThing...
# 74   [MyGene.info API, Multiomics Wellness KP API, ...
# 79   [BioThings MGIgene2phenotype API, BioThings EB...
# 128  [BioThings MGIgene2phenotype API, BioThings EB...
# 136  [BioThings IDISK API, Multiomics EHR Risk KP A...
# 127  [MyDisease.info API, Multiomics EHR Risk KP AP...
# 198  [CTD API, BioThings Rhea API, MyChem.info API,...
# 47   [Ontology Lookup Service API, MyDisease.info A...
# 200  [BioThings IDISK API, Multiomics EHR Risk KP A...
# 55   [MyDisease.info API, Multiomics EHR Risk KP AP...

# %%
api_stats.to_csv("results/api_stats.tsv", sep="\t", index=False)

# %% [markdown]
# ### by subject, object; count # of predicates

# %%
df1 = df_bte[["subject","object","predicate"]].drop_duplicates()
predicate_stats = df1.groupby(['subject','object'], group_keys=False)['predicate'].nunique().rename("count").to_frame()
predicate_stats['list'] = df1.groupby(['subject','object'], group_keys=False)['predicate'].unique().apply(list)
predicate_stats = predicate_stats.reset_index().sort_values(by=['count'],ascending=False)

predicate_stats.head(15)
# Out:
#                  subject               object  count  \
# 47               Disease              Disease     26
# 74                  Gene                 Gene     16
# 61               Disease        SmallMolecule     15
# 84                  Gene        SmallMolecule     15
# 112  PathologicalProcess              Disease     15
# 53               Disease  PathologicalProcess     15
# 196        SmallMolecule                 Gene     15
# 195        SmallMolecule              Disease     15
# 50               Disease                 Gene     13
# 73                  Gene              Disease     13
# 205        SmallMolecule        SmallMolecule     12
# 117  PathologicalProcess  PathologicalProcess     11
# 200        SmallMolecule    PhenotypicFeature     10
# 155          Polypeptide              Disease     10
# 162          Polypeptide          Polypeptide     10
#
#                                                   list
# 47   [superclass_of, subclass_of, contributes_to, c...
# 74   [homologous_to, correlated_with, physically_in...
# 61   [related_to, treated_by, has_contraindication,...
# 84   [related_to, interacts_with, physically_intera...
# 112  [coexists_with, caused_by, causes, affected_by...
# 53   [coexists_with, causes, caused_by, affects, pr...
# 196  [related_to, interacts_with, affects, physical...
# 195  [related_to, treats, contraindicated_for, has_...
# 50   [related_to, condition_associated_with_gene, a...
# 73   [gene_associated_with_condition, affects, rela...
# 205  [interacts_with, correlated_with, related_to, ...
# 117  [coexists_with, causes, caused_by, affects, af...
# 200  [has_adverse_event, associated_with, treats, c...
# 155  [related_to, causes, affects, predisposes, pro...
# 162  [interacts_with, affects, affected_by, coexist...

# %%
predicate_stats.to_csv("results/predicate_stats.tsv", sep="\t", index=False)

# %% [markdown]
# ## Filter by most common types

# %% [markdown]
# Filter to only include the most common types of entities.  Also, since we _mostly_ have the same info in both directions, only keep one direction to simplify visualization

# %%
pd.concat([df_bte['subject'], df_bte['object']]).value_counts().head(20)
# Out:
# Disease                     323
# Gene                        266
# SmallMolecule               256
# Polypeptide                 182
# PathologicalProcess         174
# ChemicalEntity              132
# PhenotypicFeature           129
# PhysiologicalProcess        124
# Procedure                    80
# Cell                         72
# CellularComponent            71
# GrossAnatomicalStructure     70
# MolecularActivity            62
# Protein                      40
# AnatomicalEntity             18
# Drug                         16
# BiologicalProcess            15
# SequenceVariant              15
# Food                         14
# ClinicalFinding              12
# dtype: int64

# %%
NUM_TYPES_TO_KEEP = 8

keep = set(pd.concat([df_bte['subject'], df_bte['object']]).value_counts().head(NUM_TYPES_TO_KEEP).keys())
keep
# Out:
# {'ChemicalEntity',
#  'Disease',
#  'Gene',
#  'PathologicalProcess',
#  'PhenotypicFeature',
#  'PhysiologicalProcess',
#  'Polypeptide',
#  'SmallMolecule'}

# %%
predicate_stats_filt = predicate_stats.query("subject in @keep & object in @keep & subject <= object").sort_values(by=['count'], ascending=False)
predicate_stats_filt.to_csv("results/predicate_stats_filt.tsv", sep="\t")
predicate_stats_filt
# Out:
#                   subject                object  count  \
# 47                Disease               Disease     26
# 74                   Gene                  Gene     16
# 61                Disease         SmallMolecule     15
# 84                   Gene         SmallMolecule     15
# 53                Disease   PathologicalProcess     15
# 50                Disease                  Gene     13
# 205         SmallMolecule         SmallMolecule     12
# 117   PathologicalProcess   PathologicalProcess     11
# 136     PhenotypicFeature         SmallMolecule     10
# 57                Disease           Polypeptide     10
# 162           Polypeptide           Polypeptide     10
# 123   PathologicalProcess         SmallMolecule      9
# 81                   Gene           Polypeptide      9
# 55                Disease     PhenotypicFeature      9
# 56                Disease  PhysiologicalProcess      9
# 165           Polypeptide         SmallMolecule      9
# 120   PathologicalProcess           Polypeptide      9
# 31         ChemicalEntity               Disease      8
# 32         ChemicalEntity                  Gene      7
# 147  PhysiologicalProcess  PhysiologicalProcess      7
# 133     PhenotypicFeature           Polypeptide      7
# 79                   Gene     PhenotypicFeature      7
# 35         ChemicalEntity   PathologicalProcess      7
# 38         ChemicalEntity           Polypeptide      7
# 131     PhenotypicFeature     PhenotypicFeature      7
# 77                   Gene   PathologicalProcess      6
# 148  PhysiologicalProcess           Polypeptide      6
# 151  PhysiologicalProcess         SmallMolecule      6
# 119   PathologicalProcess  PhysiologicalProcess      6
# 30         ChemicalEntity        ChemicalEntity      6
# 40         ChemicalEntity         SmallMolecule      5
# 37         ChemicalEntity  PhysiologicalProcess      4
# 36         ChemicalEntity     PhenotypicFeature      4
# 80                   Gene  PhysiologicalProcess      4
# 118   PathologicalProcess     PhenotypicFeature      4
# 132     PhenotypicFeature  PhysiologicalProcess      3
#
#                                                   list
# 47   [superclass_of, subclass_of, contributes_to, c...
# 74   [homologous_to, correlated_with, physically_in...
# 61   [related_to, treated_by, has_contraindication,...
# 84   [related_to, interacts_with, physically_intera...
# 53   [coexists_with, causes, caused_by, affects, pr...
# 50   [related_to, condition_associated_with_gene, a...
# 205  [interacts_with, correlated_with, related_to, ...
# 117  [coexists_with, causes, caused_by, affects, af...
# 136  [adverse_event_of, associated_with, treated_by...
# 57   [related_to, caused_by, affected_by, has_predi...
# 162  [interacts_with, affects, affected_by, coexist...
# 123  [treated_by, caused_by, related_to, prevented_...
# 81   [affected_by, coexists_with, interacts_with, p...
# 55   [has_phenotype, associated_with, related_to, c...
# 56   [contains_process, related_to, causes, affects...
# 165  [has_part, interacts_with, affects, coexists_w...
# 120  [related_to, caused_by, affected_by, has_predi...
# 31   [related_to, prevents, causes, produced_by, af...
# 32   [affects, interacts_with, produced_by, coexist...
# 147  [coexists_with, affects, affected_by, causes, ...
# 133  [related_to, affected_by, disrupted_by, has_pr...
# 79   [related_to, causes, affects, disrupts, predis...
# 35   [causes, related_to, produced_by, affects, pre...
# 38   [interacts_with, coexists_with, affected_by, a...
# 131  [superclass_of, subclass_of, associated_with, ...
# 77   [related_to, affects, causes, predisposes, dis...
# 148  [affected_by, disrupted_by, caused_by, affects...
# 151  [caused_by, disrupted_by, affected_by, affects...
# 119  [causes, affected_by, affects, precedes, disru...
# 30   [coexists_with, interacts_with, affects, affec...
# 40   [coexists_with, interacts_with, affects, affec...
# 37            [produced_by, affects, disrupts, causes]
# 36          [causes, related_to, affects, predisposes]
# 80            [causes, affects, disrupts, affected_by]
# 118  [causes, predisposes, has_manifestation, coexi...
# 132             [related_to, causes, manifestation_of]

# %%
api_stats_filt = api_stats.query("subject in @keep & object in @keep & subject <= object").sort_values(by=['count'], ascending=False)
api_stats_filt.to_csv("results/api_stats_filt.tsv", sep="\t")
api_stats_filt
# Out:
#                   subject                object  count  \
# 50                Disease                  Gene     12
# 61                Disease         SmallMolecule      9
# 84                   Gene         SmallMolecule      9
# 74                   Gene                  Gene      6
# 79                   Gene     PhenotypicFeature      5
# 136     PhenotypicFeature         SmallMolecule      4
# 47                Disease               Disease      4
# 55                Disease     PhenotypicFeature      4
# 205         SmallMolecule         SmallMolecule      4
# 131     PhenotypicFeature     PhenotypicFeature      3
# 40         ChemicalEntity         SmallMolecule      1
# 32         ChemicalEntity                  Gene      1
# 35         ChemicalEntity   PathologicalProcess      1
# 37         ChemicalEntity  PhysiologicalProcess      1
# 38         ChemicalEntity           Polypeptide      1
# 77                   Gene   PathologicalProcess      1
# 53                Disease   PathologicalProcess      1
# 56                Disease  PhysiologicalProcess      1
# 57                Disease           Polypeptide      1
# 30         ChemicalEntity        ChemicalEntity      1
# 80                   Gene  PhysiologicalProcess      1
# 31         ChemicalEntity               Disease      1
# 147  PhysiologicalProcess  PhysiologicalProcess      1
# 36         ChemicalEntity     PhenotypicFeature      1
# 165           Polypeptide         SmallMolecule      1
# 162           Polypeptide           Polypeptide      1
# 151  PhysiologicalProcess         SmallMolecule      1
# 148  PhysiologicalProcess           Polypeptide      1
# 132     PhenotypicFeature  PhysiologicalProcess      1
# 123   PathologicalProcess         SmallMolecule      1
# 120   PathologicalProcess           Polypeptide      1
# 119   PathologicalProcess  PhysiologicalProcess      1
# 118   PathologicalProcess     PhenotypicFeature      1
# 117   PathologicalProcess   PathologicalProcess      1
# 133     PhenotypicFeature           Polypeptide      1
# 81                   Gene           Polypeptide      1
#
#                                                   list
# 50   [CTD API, MyDisease.info API, MyVariant.info A...
# 61   [CTD API, MyDisease.info API, MyChem.info API,...
# 84   [CTD API, MyChem.info API, BioThings BindingDB...
# 74   [MyGene.info API, Multiomics Wellness KP API, ...
# 79   [BioThings MGIgene2phenotype API, BioThings EB...
# 136  [BioThings IDISK API, Multiomics EHR Risk KP A...
# 47   [Ontology Lookup Service API, MyDisease.info A...
# 55   [MyDisease.info API, Multiomics EHR Risk KP AP...
# 205  [BioThings DDInter API, BioThings IDISK API, M...
# 131  [BioThings HPO API, Multiomics EHR Risk KP API...
# 40                            [BioThings SEMMEDDB API]
# 32                            [BioThings SEMMEDDB API]
# 35                            [BioThings SEMMEDDB API]
# 37                            [BioThings SEMMEDDB API]
# 38                            [BioThings SEMMEDDB API]
# 77                            [BioThings SEMMEDDB API]
# 53                            [BioThings SEMMEDDB API]
# 56                            [BioThings SEMMEDDB API]
# 57                            [BioThings SEMMEDDB API]
# 30                            [BioThings SEMMEDDB API]
# 80                            [BioThings SEMMEDDB API]
# 31                            [BioThings SEMMEDDB API]
# 147                           [BioThings SEMMEDDB API]
# 36                            [BioThings SEMMEDDB API]
# 165                           [BioThings SEMMEDDB API]
# 162                           [BioThings SEMMEDDB API]
# 151                           [BioThings SEMMEDDB API]
# 148                           [BioThings SEMMEDDB API]
# 132                           [BioThings SEMMEDDB API]
# 123                           [BioThings SEMMEDDB API]
# 120                           [BioThings SEMMEDDB API]
# 119                           [BioThings SEMMEDDB API]
# 118                           [BioThings SEMMEDDB API]
# 117                           [BioThings SEMMEDDB API]
# 133                           [BioThings SEMMEDDB API]
# 81                            [BioThings SEMMEDDB API]

# %% [markdown]
# ## Export to graphml

# %%
def create_graph(df2, filename):
    G = nx.Graph()

    node_types = set(pd.concat([df2['subject'], df2['object']]))
        
    for node_type in node_types:
        G.add_node(node_type, label = add_spacing(node_type))

    for index,row in df2.iterrows():
        if 'count' in row.keys():
            G.add_edge(row['subject'], row['object'], weight=row['count'])
        else:
            G.add_edge(row['subject'], row['object'])
    
    nx.write_graphml(G, filename, infer_numeric_types=True)

# %%
def add_spacing(str):
    key = {
        "BiologicalProcess":               "Biological\nProcess",
        "ChemicalEntity":                  "Chemical\nEntity",
        "MolecularMixture":                "Molecular\nMixture", 
        "PhysiologicalProcess":            "Physiological\nProcess",
        "SmallMolecule":                   "Small\nMolecule",
        "PhenotypicFeature":               "Phenotypic\nFeature",
        'ChemicalExposure':                'Chemical\nExposure',
        'ClinicalAttribute':               'Clinical\nAttribute',
        'ClinicalIntervention':            'Clinical\nIntervention',
        'ComplexMolecularMixture':         'Complex\nMolecular\nMixture',
        'EnvironmentalExposure':           'Environmental\nExposure',
        'InformationContentEntity':        'Information\nContentEntity',
        'MolecularMixture':                'Molecular\nMixture',
        'PhysiologicalProcess':            'Physiological\nProcess',
        'PopulationOfIndividualOrganisms': 'PopulationOf\nIndividualOrganisms',
        'GrossAnatomicalStructure':        'Gross\nAnatomical\nStructure',
        'PathologicalProcess':             'Pathological\nProcess'
    }
    if str in key.keys():
        return(key[str])
    else:
        return(str)

# %%
create_graph(api_stats_filt, "results/api_stats_filt.graphml")
create_graph(predicate_stats_filt, "results/predicate_stats_filt.graphml")

# %% [markdown]
# ## Restricted subway diagram
#
# Ultimately wasn't able to get a usable figure out of this, but keeping this section in case I want to experiment with this again later.

# %%
NUM_TYPES_TO_KEEP = 5

keep = set(pd.concat([df_bte['subject'], df_bte['object']]).value_counts().head(NUM_TYPES_TO_KEEP).keys())
keep
# Out:
# {'Disease', 'Gene', 'PathologicalProcess', 'Polypeptide', 'SmallMolecule'}

# %%
df_subway = df_bte.query('object in @keep & subject in @keep & subject < object').drop(columns=['predicate']).drop_duplicates()
df_subway
# Out:
#                     subject               object  \
# 17394                  Gene        SmallMolecule
# 17395               Disease        SmallMolecule
# 17400               Disease                 Gene
# 65526               Disease                 Gene
# 65530               Disease        SmallMolecule
# 65553               Disease                 Gene
# 66886               Disease                 Gene
# 67276               Disease        SmallMolecule
# 67282                  Gene        SmallMolecule
# 67312                  Gene        SmallMolecule
# 67314                  Gene        SmallMolecule
# 67316               Disease        SmallMolecule
# 67318               Disease                 Gene
# 67320               Disease                 Gene
# 67368               Disease                 Gene
# 67380               Disease                 Gene
# 195392              Disease        SmallMolecule
# 195394              Disease        SmallMolecule
# 201181                 Gene        SmallMolecule
# 246095                 Gene        SmallMolecule
# 291136              Disease        SmallMolecule
# 291205                 Gene        SmallMolecule
# 291210              Disease                 Gene
# 291236              Disease        SmallMolecule
# 291244                 Gene          Polypeptide
# 291246          Polypeptide        SmallMolecule
# 291251              Disease          Polypeptide
# 291260              Disease                 Gene
# 291278                 Gene        SmallMolecule
# 291289              Disease  PathologicalProcess
# 291370  PathologicalProcess          Polypeptide
# 291422                 Gene  PathologicalProcess
# 291432  PathologicalProcess        SmallMolecule
# 293721              Disease                 Gene
# 293742              Disease        SmallMolecule
# 293750                 Gene        SmallMolecule
# 293762              Disease                 Gene
#
#                                      api_name  \
# 17394                                 CTD API
# 17395                                 CTD API
# 17400                                 CTD API
# 65526                      MyDisease.info API
# 65530                      MyDisease.info API
# 65553                      MyVariant.info API
# 66886                         MyGene.info API
# 67276                         MyChem.info API
# 67282                         MyChem.info API
# 67312                 BioThings BindingDB API
# 67314                     BioThings PFOCR API
# 67316                     BioThings PFOCR API
# 67318                     BioThings PFOCR API
# 67320                  BioThings DISEASES API
# 67368         BioThings MGIgene2phenotype API
# 67380         BioThings EBIgene2phenotype API
# 195392                     BioThings GTRx API
# 195394                    BioThings IDISK API
# 201181                    BioThings DGIdb API
# 246095             Multiomics Wellness KP API
# 291136             Multiomics EHR Risk KP API
# 291205  Multiomics BigGIM-DrugResponse KP API
# 291210  Multiomics BigGIM-DrugResponse KP API
# 291236                 BioThings SEMMEDDB API
# 291244                 BioThings SEMMEDDB API
# 291246                 BioThings SEMMEDDB API
# 291251                 BioThings SEMMEDDB API
# 291260                 BioThings SEMMEDDB API
# 291278                 BioThings SEMMEDDB API
# 291289                 BioThings SEMMEDDB API
# 291370                 BioThings SEMMEDDB API
# 291422                 BioThings SEMMEDDB API
# 291432                 BioThings SEMMEDDB API
# 293721                            BioLink API
# 293742   Text Mining Targeted Association API
# 293750   Text Mining Targeted Association API
# 293762   Text Mining Targeted Association API
#
#                                   api_id
# 17394   0212611d1c670f9107baf00b77f0889a
# 17395   0212611d1c670f9107baf00b77f0889a
# 17400   0212611d1c670f9107baf00b77f0889a
# 65526   671b45c0301c8624abbd26ae78449ca2
# 65530   671b45c0301c8624abbd26ae78449ca2
# 65553   09c8782d9f4027712e65b95424adba79
# 66886   59dce17363dce279d389100834e43648
# 67276   8f08d1446e0bb9c2b323713ce83e2bd3
# 67282   8f08d1446e0bb9c2b323713ce83e2bd3
# 67312   38e9e5169a72aee3659c9ddba956790d
# 67314   edeb26858bd27d0322af93e7a9e08761
# 67316   edeb26858bd27d0322af93e7a9e08761
# 67318   edeb26858bd27d0322af93e7a9e08761
# 67320   a7f784626a426d054885a5f33f17d3f8
# 67368   77ed27f111262d0289ed4f4071faa619
# 67380   1f47552dabd67351d4c625adb0a10d00
# 195392  316eab811fd9ef1097df98bcaa9f7361
# 195394  32f36164fabed5d3abe6c2fd899c9418
# 201181  e3edd325c76f2992a111b43a907a4870
# 246095  02af7d098ab304e80d6f4806c3527027
# 291136  d86a24f6027ffe778f84ba10a7a1861a
# 291205  adf20dd6ff23dfe18e8e012bde686e31
# 291210  adf20dd6ff23dfe18e8e012bde686e31
# 291236  1d288b3a3caf75d541ffaae3aab386c8
# 291244  1d288b3a3caf75d541ffaae3aab386c8
# 291246  1d288b3a3caf75d541ffaae3aab386c8
# 291251  1d288b3a3caf75d541ffaae3aab386c8
# 291260  1d288b3a3caf75d541ffaae3aab386c8
# 291278  1d288b3a3caf75d541ffaae3aab386c8
# 291289  1d288b3a3caf75d541ffaae3aab386c8
# 291370  1d288b3a3caf75d541ffaae3aab386c8
# 291422  1d288b3a3caf75d541ffaae3aab386c8
# 291432  1d288b3a3caf75d541ffaae3aab386c8
# 293721  d22b657426375a5295e7da8a303b9893
# 293742  978fe380a147a8641caf72320862697b
# 293750  978fe380a147a8641caf72320862697b
# 293762  978fe380a147a8641caf72320862697b

# %%
G = nx.MultiGraph()

df2 = df_subway

node_types = set(pd.concat([df2['subject'], df2['object']]))
        
for node_type in node_types:
    G.add_node(node_type, label = add_spacing(node_type))

# %%
idcount = 0
for index,row in df2.iterrows():
    G.add_edge(row['subject'], row['object'], api_name=row['api_name'], key=idcount)
    idcount = idcount + 1

# %%
nx.write_graphml(G, "results/subway.graphml", infer_numeric_types=True,named_key_ids=True)

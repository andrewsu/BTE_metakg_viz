# %% [markdown]
# # BTE metakg visualization
#
# The goal of this notebook is to visualize the metaKG that BTE uses.  Similar to the [subway diagram](https://raw.githubusercontent.com/biothings/BioThings_Explorer_TRAPI/main/diagrams/smartapi_metagraph.png) we've used before, but updated to the size and scale of the current metakg.
#
# This notebook takes as input an ndson file with the SmartAPI metakg (originally provided by Chunlei on 2023-03-01).
#
# Optimizations
# * remove less-commonly-used node types from subject/object
# * only count in one direction (`A-treats-B` gets merged with `B-treated_by-A`)

# %%
import biothings_client
import json5
import networkx as nx
import pandas as pd
import re
import requests

# %% [markdown]
# ## Read in data

# %% [markdown]
# ### Option 1 -- Read in the Smart API ndjson file

# %%
df = pd.read_json('data/smartapi_metakg_03012023.ndjson.gz', lines=True)
df
# Out:
#                  subject             object  \
# 0       AnatomicalEntity  MolecularActivity
# 1       AnatomicalEntity    MolecularEntity
# 2       AnatomicalEntity         NamedThing
# 3       AnatomicalEntity  NucleicAcidEntity
# 4       AnatomicalEntity          Occurrent
# ...                  ...                ...
# 175543              Cell         Phenomenon
# 175544        Transcript           CellLine
# 175545           Disease  PhenotypicFeature
# 175546            Device            Vitamin
# 175547         Procedure          Procedure
#
#                                  predicate  \
# 0                      affects_activity_of
# 1                      affects_activity_of
# 2                      affects_activity_of
# 3                      affects_activity_of
# 4                      affects_activity_of
# ...                                    ...
# 175543                              causes
# 175544           physically_interacts_with
# 175545  entity_positively_regulates_entity
# 175546  entity_negatively_regulates_entity
# 175547                     has_participant
#
#                                                       api provided_by
# 0       {'name': 'CAM-KP API', 'smartapi': {'metadata'...         NaN
# 1       {'name': 'CAM-KP API', 'smartapi': {'metadata'...         NaN
# 2       {'name': 'CAM-KP API', 'smartapi': {'metadata'...         NaN
# 3       {'name': 'CAM-KP API', 'smartapi': {'metadata'...         NaN
# 4       {'name': 'CAM-KP API', 'smartapi': {'metadata'...         NaN
# ...                                                   ...         ...
# 175543  {'name': 'ARAX Translator Reasoner - TRAPI 1.3...         NaN
# 175544  {'name': 'ARAX Translator Reasoner - TRAPI 1.3...         NaN
# 175545  {'name': 'ARAX Translator Reasoner - TRAPI 1.3...         NaN
# 175546  {'name': 'ARAX Translator Reasoner - TRAPI 1.3...         NaN
# 175547  {'name': 'ARAX Translator Reasoner - TRAPI 1.3...         NaN
#
# [175548 rows x 5 columns]

# %% [markdown]
# ### Option 2 (preferred) -- Query the SmartAPI API
#
# This method takes longer, but it retrieves the most up-to-date data

# %%
c = biothings_client.get_client('metakg', url='https://dev.smart-api.info/api/metakg')
c._query_endpoint=''
a = c.query('*', fetch_all=True)

# %%
df = pd.DataFrame(a)
df
# Out:
# Fetching 304687 metakg(s) . . .
# No more results to return.
#                                                       api  \
# 0       {'name': 'CAM-KP API', 'smartapi': {'id': '480...
# 1       {'name': 'CAM-KP API', 'smartapi': {'id': '480...
# 2       {'name': 'CAM-KP API', 'smartapi': {'id': '480...
# 3       {'name': 'CAM-KP API', 'smartapi': {'id': '480...
# 4       {'name': 'CAM-KP API', 'smartapi': {'id': '480...
# ...                                                   ...
# 304682  {'name': 'ARAX Translator Reasoner - TRAPI 1.3...
# 304683  {'name': 'ARAX Translator Reasoner - TRAPI 1.3...
# 304684  {'name': 'ARAX Translator Reasoner - TRAPI 1.3...
# 304685  {'name': 'ARAX Translator Reasoner - TRAPI 1.3...
# 304686  {'name': 'ARAX Translator Reasoner - TRAPI 1.3...
#
#                             object                           predicate  \
# 0                             Gene             entity_regulates_entity
# 1                GeneOrGeneProduct             entity_regulates_entity
# 2                 GeneProductMixin             entity_regulates_entity
# 3                    GenomicEntity             entity_regulates_entity
# 4       MacromolecularComplexMixin             entity_regulates_entity
# ...                            ...                                 ...
# 304682                  Phenomenon                              causes
# 304683                    CellLine           physically_interacts_with
# 304684           PhenotypicFeature  entity_positively_regulates_entity
# 304685                     Vitamin  entity_negatively_regulates_entity
# 304686                   Procedure                     has_participant
#
#                            subject provided_by
# 0       MacromolecularMachineMixin         NaN
# 1       MacromolecularMachineMixin         NaN
# 2       MacromolecularMachineMixin         NaN
# 3       MacromolecularMachineMixin         NaN
# 4       MacromolecularMachineMixin         NaN
# ...                            ...         ...
# 304682                        Cell         NaN
# 304683                  Transcript         NaN
# 304684                     Disease         NaN
# 304685                      Device         NaN
# 304686                   Procedure         NaN
#
# [304687 rows x 5 columns]

# %% [markdown]
# parse out a couple lines for the API name and ID

# %%
df = df.assign(api_name = lambda x: pd.json_normalize(x['api'])['name'])
df = df.assign(api_id = lambda x: pd.json_normalize(x['api'])['smartapi.id'])
df
# Out:
#                                                       api  \
# 0       {'name': 'CAM-KP API', 'smartapi': {'id': '480...
# 1       {'name': 'CAM-KP API', 'smartapi': {'id': '480...
# 2       {'name': 'CAM-KP API', 'smartapi': {'id': '480...
# 3       {'name': 'CAM-KP API', 'smartapi': {'id': '480...
# 4       {'name': 'CAM-KP API', 'smartapi': {'id': '480...
# ...                                                   ...
# 304682  {'name': 'ARAX Translator Reasoner - TRAPI 1.3...
# 304683  {'name': 'ARAX Translator Reasoner - TRAPI 1.3...
# 304684  {'name': 'ARAX Translator Reasoner - TRAPI 1.3...
# 304685  {'name': 'ARAX Translator Reasoner - TRAPI 1.3...
# 304686  {'name': 'ARAX Translator Reasoner - TRAPI 1.3...
#
#                             object                           predicate  \
# 0                             Gene             entity_regulates_entity
# 1                GeneOrGeneProduct             entity_regulates_entity
# 2                 GeneProductMixin             entity_regulates_entity
# 3                    GenomicEntity             entity_regulates_entity
# 4       MacromolecularComplexMixin             entity_regulates_entity
# ...                            ...                                 ...
# 304682                  Phenomenon                              causes
# 304683                    CellLine           physically_interacts_with
# 304684           PhenotypicFeature  entity_positively_regulates_entity
# 304685                     Vitamin  entity_negatively_regulates_entity
# 304686                   Procedure                     has_participant
#
#                            subject provided_by  \
# 0       MacromolecularMachineMixin         NaN
# 1       MacromolecularMachineMixin         NaN
# 2       MacromolecularMachineMixin         NaN
# 3       MacromolecularMachineMixin         NaN
# 4       MacromolecularMachineMixin         NaN
# ...                            ...         ...
# 304682                        Cell         NaN
# 304683                  Transcript         NaN
# 304684                     Disease         NaN
# 304685                      Device         NaN
# 304686                   Procedure         NaN
#
#                                       api_name  \
# 0                                   CAM-KP API
# 1                                   CAM-KP API
# 2                                   CAM-KP API
# 3                                   CAM-KP API
# 4                                   CAM-KP API
# ...                                        ...
# 304682  ARAX Translator Reasoner - TRAPI 1.3.0
# 304683  ARAX Translator Reasoner - TRAPI 1.3.0
# 304684  ARAX Translator Reasoner - TRAPI 1.3.0
# 304685  ARAX Translator Reasoner - TRAPI 1.3.0
# 304686  ARAX Translator Reasoner - TRAPI 1.3.0
#
#                                   api_id
# 0       4803457bdb4bfeeb63a88244830ece2e
# 1       4803457bdb4bfeeb63a88244830ece2e
# 2       4803457bdb4bfeeb63a88244830ece2e
# 3       4803457bdb4bfeeb63a88244830ece2e
# 4       4803457bdb4bfeeb63a88244830ece2e
# ...                                  ...
# 304682  e248aefca0f469229e82cca80fbabc89
# 304683  e248aefca0f469229e82cca80fbabc89
# 304684  e248aefca0f469229e82cca80fbabc89
# 304685  e248aefca0f469229e82cca80fbabc89
# 304686  e248aefca0f469229e82cca80fbabc89
#
# [304687 rows x 7 columns]

# %% [markdown]
# Read in the BTE config file that specifies currently-allowed APIs

# %%
bte_config_url = "https://raw.githubusercontent.com/biothings/BioThings_Explorer_TRAPI/main/src/config/apis.js"
r = requests.get(bte_config_url)
str_bte_config = r.text
#print(str_bte_config)
str_bte_config = re.sub("exports.API_LIST = ",  "", str_bte_config)                       # remove variable assignment step
str_bte_config = re.sub("\s*//.*",              "", str_bte_config)                       # remove commented lines
str_bte_config = re.sub(r'^$\n',                '', str_bte_config, flags=re.MULTILINE)   # remove blank lines
str_bte_config = re.sub(r',\s*exclude:[^\]]*]', '', str_bte_config, flags=re.MULTILINE)   # remove 'exclude' section
str_bte_config = re.sub(r';$',                  '', str_bte_config, flags=re.MULTILINE)   # remove 'exclude' section
#print(str_bte_config)

bte_config = json5.loads(str_bte_config)
bte_config
# Out:
# {'include': [{'id': 'd22b657426375a5295e7da8a303b9893', 'name': 'BioLink API'},
#   {'id': '43af91b3d7cae43591083bff9d75c6dd', 'name': 'EBI Proteins API'},
#   {'id': 'dca415f2d792976af9d642b7e73f7a41', 'name': 'LitVar API'},
#   {'id': '1f277e1563fcfd124bfae2cc3c4bcdec', 'name': 'QuickGO API'},
#   {'id': '1c056ffc7ed0dd1229e71c4752239465',
#    'name': 'Ontology Lookup Service API'},
#   {'id': '38e9e5169a72aee3659c9ddba956790d',
#    'name': 'BioThings BindingDB API'},
#   {'id': '55a223c6c6e0291dbd05f2faf27d16f4',
#    'name': 'BioThings BioPlanet Pathway-Disease API'},
#   {'id': 'b99c6dd64abcefe87dcd0a51c249ee6d',
#    'name': 'BioThings BioPlanet Pathway-Gene API'},
#   {'id': '00fb85fc776279163199e6c50f6ddfc6', 'name': 'BioThings DDInter API'},
#   {'id': 'e3edd325c76f2992a111b43a907a4870', 'name': 'BioThings DGIdb API'},
#   {'id': 'a7f784626a426d054885a5f33f17d3f8', 'name': 'BioThings DISEASES API'},
#   {'id': '1f47552dabd67351d4c625adb0a10d00',
#    'name': 'BioThings EBIgene2phenotype API'},
#   {'id': 'cc857d5b7c8b7609b5bbb38ff990bfff',
#    'name': 'BioThings GO Biological Process API'},
#   {'id': 'f339b28426e7bf72028f60feefcd7465',
#    'name': 'BioThings GO Cellular Component API'},
#   {'id': '34bad236d77bea0a0ee6c6cba5be54a6',
#    'name': 'BioThings GO Molecular Function API'},
#   {'id': '316eab811fd9ef1097df98bcaa9f7361', 'name': 'BioThings GTRx API'},
#   {'id': 'a5b0ec6bfde5008984d4b6cde402d61f', 'name': 'BioThings HPO API'},
#   {'id': '32f36164fabed5d3abe6c2fd899c9418', 'name': 'BioThings IDISK API'},
#   {'id': '77ed27f111262d0289ed4f4071faa619',
#    'name': 'BioThings MGIgene2phenotype API'},
#   {'id': 'edeb26858bd27d0322af93e7a9e08761', 'name': 'BioThings PFOCR API'},
#   {'id': '03283cc2b21c077be6794e1704b1d230', 'name': 'BioThings Rhea API'},
#   {'id': '1d288b3a3caf75d541ffaae3aab386c8', 'name': 'BioThings SEMMEDDB API'},
#   {'id': 'ec6d76016ef40f284359d17fbf78df20', 'name': 'BioThings UBERON API'},
#   {'id': '8f08d1446e0bb9c2b323713ce83e2bd3', 'name': 'MyChem.info API'},
#   {'id': '671b45c0301c8624abbd26ae78449ca2', 'name': 'MyDisease.info API'},
#   {'id': '59dce17363dce279d389100834e43648', 'name': 'MyGene.info API'},
#   {'id': '09c8782d9f4027712e65b95424adba79', 'name': 'MyVariant.info API'},
#   {'id': 'adf20dd6ff23dfe18e8e012bde686e31',
#    'name': 'Multiomics BigGIM-DrugResponse KP API'},
#   {'id': '08a5ddcde71b4bf838327ef469076acd',
#    'name': 'Multiomics ClinicalTrials KP'},
#   {'id': 'd86a24f6027ffe778f84ba10a7a1861a',
#    'name': 'Multiomics EHR Risk KP API'},
#   {'id': '02af7d098ab304e80d6f4806c3527027',
#    'name': 'Multiomics Wellness KP API'},
#   {'id': '978fe380a147a8641caf72320862697b',
#    'name': 'Text Mining Targeted Association API'},
#   {'id': '25085b05fd1afcebb497724d147cfb44',
#    'name': 'Automat-biolink(Trapi v1.3.0)'},
#   {'id': '89aa98098ba4329aa49b43ff8d21ffbb',
#    'name': 'Automat-ctd(Trapi v1.3.0)'},
#   {'id': '463525b319d7e1ef8f705bce953d01bd',
#    'name': 'Automat-cord19(Trapi v1.3.0)'},
#   {'id': '539873b1f2f2eb913efaee411e09eaa7',
#    'name': 'Automat-drug-central(Trapi v1.3.0)'},
#   {'id': '272c2357763e4faf737f1cba94beaa1d',
#    'name': 'Automat-gtex(Trapi v1.3.0)'},
#   {'id': 'fb1f3780ad67b030cb0617363afa8f61',
#    'name': 'Automat-gwas-catalog(Trapi v1.3.0)'},
#   {'id': 'aacdd9e863bb659574d302f084084976',
#    'name': 'Automat-gtopdb(Trapi v1.3.0)'},
#   {'id': '7382f0fabffce3cc7f7b8b6358c69259',
#    'name': 'Automat-hgnc(Trapi v1.3.0)'},
#   {'id': 'ee2d2eae42ca30fe82946d3f42febaa0',
#    'name': 'Automat-hmdb(Trapi v1.3.0)'},
#   {'id': '830600da121a5accc955cbf62e60f802',
#    'name': 'Automat-hetio(Trapi v1.3.0)'},
#   {'id': 'f30339a6894a146a19a34974712ca2e3',
#    'name': 'Automat-human-goa(Trapi v1.3.0)'},
#   {'id': '44e7a1147ca8657f50af6bb25982762d',
#    'name': 'Automat-icees-kg(Trapi v1.3.0)'},
#   {'id': 'e0687431a9ff88344d20e83e0c99ee7d',
#    'name': 'Automat-intact(Trapi v1.3.0)'},
#   {'id': '4c6f9117581531161849e60ea906f0be',
#    'name': 'Automat-ontology-hierarchy(Trapi v1.3.0)'},
#   {'id': '2a879882329b000c7e7f08c2d71ccffd',
#    'name': 'Automat-panther(Trapi v1.3.0)'},
#   {'id': '0295640b4d060133e4296dda4c31da47',
#    'name': 'Automat-pharos(Trapi v1.3.0)'},
#   {'id': 'ef9027a7d2246c6540cc7b3ce202d89f',
#    'name': 'Automat-uberongraph(Trapi v1.3.0)'},
#   {'id': '79310edd01cae96f3d8495250e625886',
#    'name': 'Automat-viral-proteome(Trapi v1.3.0)'},
#   {'id': '51c178099fa2dc99b5d8fff8bf9f1a0d', 'name': 'COHD TRAPI 1.3'},
#   {'id': '855adaa128ce5aa58a091d99e520d396',
#    'name': 'Connections Hypothesis Provider API'}]}

# %%
bte_config_ids = [ x['id'] for x in bte_config['include'] ]
bte_config_ids
# Out:
# ['d22b657426375a5295e7da8a303b9893',
#  '43af91b3d7cae43591083bff9d75c6dd',
#  'dca415f2d792976af9d642b7e73f7a41',
#  '1f277e1563fcfd124bfae2cc3c4bcdec',
#  '1c056ffc7ed0dd1229e71c4752239465',
#  '38e9e5169a72aee3659c9ddba956790d',
#  '55a223c6c6e0291dbd05f2faf27d16f4',
#  'b99c6dd64abcefe87dcd0a51c249ee6d',
#  '00fb85fc776279163199e6c50f6ddfc6',
#  'e3edd325c76f2992a111b43a907a4870',
#  'a7f784626a426d054885a5f33f17d3f8',
#  '1f47552dabd67351d4c625adb0a10d00',
#  'cc857d5b7c8b7609b5bbb38ff990bfff',
#  'f339b28426e7bf72028f60feefcd7465',
#  '34bad236d77bea0a0ee6c6cba5be54a6',
#  '316eab811fd9ef1097df98bcaa9f7361',
#  'a5b0ec6bfde5008984d4b6cde402d61f',
#  '32f36164fabed5d3abe6c2fd899c9418',
#  '77ed27f111262d0289ed4f4071faa619',
#  'edeb26858bd27d0322af93e7a9e08761',
#  '03283cc2b21c077be6794e1704b1d230',
#  '1d288b3a3caf75d541ffaae3aab386c8',
#  'ec6d76016ef40f284359d17fbf78df20',
#  '8f08d1446e0bb9c2b323713ce83e2bd3',
#  '671b45c0301c8624abbd26ae78449ca2',
#  '59dce17363dce279d389100834e43648',
#  '09c8782d9f4027712e65b95424adba79',
#  'adf20dd6ff23dfe18e8e012bde686e31',
#  '08a5ddcde71b4bf838327ef469076acd',
#  'd86a24f6027ffe778f84ba10a7a1861a',
#  '02af7d098ab304e80d6f4806c3527027',
#  '978fe380a147a8641caf72320862697b',
#  '25085b05fd1afcebb497724d147cfb44',
#  '89aa98098ba4329aa49b43ff8d21ffbb',
#  '463525b319d7e1ef8f705bce953d01bd',
#  '539873b1f2f2eb913efaee411e09eaa7',
#  '272c2357763e4faf737f1cba94beaa1d',
#  'fb1f3780ad67b030cb0617363afa8f61',
#  'aacdd9e863bb659574d302f084084976',
#  '7382f0fabffce3cc7f7b8b6358c69259',
#  'ee2d2eae42ca30fe82946d3f42febaa0',
#  '830600da121a5accc955cbf62e60f802',
#  'f30339a6894a146a19a34974712ca2e3',
#  '44e7a1147ca8657f50af6bb25982762d',
#  'e0687431a9ff88344d20e83e0c99ee7d',
#  '4c6f9117581531161849e60ea906f0be',
#  '2a879882329b000c7e7f08c2d71ccffd',
#  '0295640b4d060133e4296dda4c31da47',
#  'ef9027a7d2246c6540cc7b3ce202d89f',
#  '79310edd01cae96f3d8495250e625886',
#  '51c178099fa2dc99b5d8fff8bf9f1a0d',
#  '855adaa128ce5aa58a091d99e520d396']

# %% [markdown]
# ## Join SmartAPI data with BTE config IDs

# %%
df_bte = df.query('api_id in @bte_config_ids').drop(columns=['api']).drop_duplicates()
df_bte
# Out:
#                    object          predicate            subject  \
# 37865                Gene           has_part         GeneFamily
# 43365             Disease      superclass_of            Disease
# 51379      ChemicalEntity        subclass_of            Protein
# 51380      ChemicalEntity         related_to            Protein
# 51381      ChemicalEntity           overlaps            Protein
# ...                   ...                ...                ...
# 259395               Gene  contribution_from  PhenotypicFeature
# 259396  PhenotypicFeature     contributes_to      SmallMolecule
# 259397      SmallMolecule  contribution_from  PhenotypicFeature
# 259400            Disease     contributes_to      SmallMolecule
# 259401      SmallMolecule  contribution_from            Disease
#
#                      provided_by                              api_name  \
# 37865                        NaN            Automat-hgnc(Trapi v1.3.0)
# 43365   infores:disease-ontology           Ontology Lookup Service API
# 51379                        NaN     Automat-uberongraph(Trapi v1.3.0)
# 51380                        NaN     Automat-uberongraph(Trapi v1.3.0)
# 51381                        NaN     Automat-uberongraph(Trapi v1.3.0)
# ...                          ...                                   ...
# 259395                       NaN  Text Mining Targeted Association API
# 259396                       NaN  Text Mining Targeted Association API
# 259397                       NaN  Text Mining Targeted Association API
# 259400                       NaN  Text Mining Targeted Association API
# 259401                       NaN  Text Mining Targeted Association API
#
#                                   api_id
# 37865   7382f0fabffce3cc7f7b8b6358c69259
# 43365   1c056ffc7ed0dd1229e71c4752239465
# 51379   ef9027a7d2246c6540cc7b3ce202d89f
# 51380   ef9027a7d2246c6540cc7b3ce202d89f
# 51381   ef9027a7d2246c6540cc7b3ce202d89f
# ...                                  ...
# 259395  978fe380a147a8641caf72320862697b
# 259396  978fe380a147a8641caf72320862697b
# 259397  978fe380a147a8641caf72320862697b
# 259400  978fe380a147a8641caf72320862697b
# 259401  978fe380a147a8641caf72320862697b
#
# [4115 rows x 6 columns]

# %%
df_bte[['subject','object','predicate','api_name','api_id']].drop_duplicates().to_csv("results/bte_operations.tsv", sep="\t", index=False)

# %%
df_bte['api_name'].value_counts()
# Out:
# Automat-uberongraph(Trapi v1.3.0)           1368
# BioThings SEMMEDDB API                       932
# Automat-ctd(Trapi v1.3.0)                    509
# Automat-biolink(Trapi v1.3.0)                210
# Automat-hetio(Trapi v1.3.0)                  143
# Automat-ontology-hierarchy(Trapi v1.3.0)     134
# Automat-drug-central(Trapi v1.3.0)            93
# Automat-pharos(Trapi v1.3.0)                  79
# Automat-hmdb(Trapi v1.3.0)                    66
# Automat-human-goa(Trapi v1.3.0)               58
# Automat-icees-kg(Trapi v1.3.0)                55
# COHD TRAPI 1.3                                50
# Multiomics EHR Risk KP API                    44
# Automat-viral-proteome(Trapi v1.3.0)          35
# Automat-gtopdb(Trapi v1.3.0)                  33
# Automat-panther(Trapi v1.3.0)                 24
# BioLink API                                   21
# MyChem.info API                               21
# Text Mining Targeted Association API          20
# Automat-gwas-catalog(Trapi v1.3.0)            18
# Automat-gtex(Trapi v1.3.0)                    17
# Multiomics Wellness KP API                    17
# MyDisease.info API                            17
# MyVariant.info API                            16
# Multiomics BigGIM-DrugResponse KP API         14
# MyGene.info API                               13
# BioThings DGIdb API                           12
# Connections Hypothesis Provider API           12
# Automat-intact(Trapi v1.3.0)                  11
# BioThings GO Biological Process API           10
# BioThings UBERON API                           9
# BioThings IDISK API                            7
# BioThings PFOCR API                            6
# Automat-hgnc(Trapi v1.3.0)                     4
# BioThings EBIgene2phenotype API                4
# BioThings GO Molecular Function API            4
# BioThings MGIgene2phenotype API                4
# BioThings GO Cellular Component API            4
# BioThings GTRx API                             2
# Multiomics ClinicalTrials KP                   2
# BioThings BioPlanet Pathway-Disease API        2
# BioThings HPO API                              2
# BioThings DISEASES API                         2
# BioThings BioPlanet Pathway-Gene API           2
# BioThings BindingDB API                        2
# BioThings Rhea API                             2
# BioThings DDInter API                          1
# LitVar API                                     1
# QuickGO API                                    1
# EBI Proteins API                               1
# Ontology Lookup Service API                    1
# Name: api_name, dtype: int64

# %% [markdown]
# ## Summarization

# %% [markdown]
# ### by subject, object; count # of APIs

# %%
df1 = df_bte[["subject","object","api_name"]]
api_stats = df1.groupby(['subject','object'], group_keys=False)['api_name'].nunique().rename("count").to_frame()
api_stats['list'] = df1.groupby(['subject','object'], group_keys=False)['api_name'].unique().apply(list)
api_stats = api_stats.reset_index()

with pd.option_context('display.min_rows', 20,
                       'display.max_columns', None,
                       'display.precision', 3,
                       ):
    print(api_stats)
# Out:
#               subject                    object  count  \
# 0    AnatomicalEntity          AnatomicalEntity      4
# 1    AnatomicalEntity         BiologicalProcess      1
# 2    AnatomicalEntity                      Cell      3
# 3    AnatomicalEntity         CellularComponent      6
# 4    AnatomicalEntity            ChemicalEntity      1
# 5    AnatomicalEntity                   Disease      7
# 6    AnatomicalEntity                      Gene      2
# 7    AnatomicalEntity  GrossAnatomicalStructure      3
# 8    AnatomicalEntity         MolecularActivity      1
# 9    AnatomicalEntity          MolecularMixture      1
# ..                ...                       ...    ...
# 384     SmallMolecule          MolecularMixture     10
# 385     SmallMolecule       PathologicalProcess      1
# 386     SmallMolecule                   Pathway      2
# 387     SmallMolecule         PhenotypicFeature     11
# 388     SmallMolecule      PhysiologicalProcess      1
# 389     SmallMolecule               Polypeptide     10
# 390     SmallMolecule                 Procedure      3
# 391     SmallMolecule                   Protein      5
# 392     SmallMolecule             SmallMolecule     15
# 393         Treatment                   Disease      1
#
#                                                   list
# 0    [Automat-uberongraph(Trapi v1.3.0), Automat-he...
# 1                  [Automat-uberongraph(Trapi v1.3.0)]
# 2    [Automat-uberongraph(Trapi v1.3.0), Automat-bi...
# 3    [Automat-uberongraph(Trapi v1.3.0), Automat-pa...
# 4                  [Automat-uberongraph(Trapi v1.3.0)]
# 5    [Automat-uberongraph(Trapi v1.3.0), Automat-dr...
# 6    [Automat-pharos(Trapi v1.3.0), Automat-hetio(T...
# 7    [Automat-uberongraph(Trapi v1.3.0), Automat-he...
# 8                  [Automat-uberongraph(Trapi v1.3.0)]
# 9                  [Automat-uberongraph(Trapi v1.3.0)]
# ..                                                 ...
# 384  [Automat-uberongraph(Trapi v1.3.0), Automat-dr...
# 385                           [BioThings SEMMEDDB API]
# 386  [Automat-uberongraph(Trapi v1.3.0), Automat-hm...
# 387  [Automat-uberongraph(Trapi v1.3.0), Automat-dr...
# 388                           [BioThings SEMMEDDB API]
# 389  [Automat-uberongraph(Trapi v1.3.0), Automat-dr...
# 390  [COHD TRAPI 1.3, Multiomics EHR Risk KP API, B...
# 391  [Automat-uberongraph(Trapi v1.3.0), Automat-dr...
# 392  [Automat-uberongraph(Trapi v1.3.0), Automat-dr...
# 393                     [Multiomics ClinicalTrials KP]
#
# [394 rows x 4 columns]

# %%
api_stats.to_csv("results/api_stats.tsv", sep="\t", index=False)

# %% [markdown]
# ### by subject, object; count # of predicates

# %%
df1 = df_bte[["subject","object","predicate"]]
predicate_stats = df1.groupby(['subject','object'], group_keys=False)['predicate'].nunique().rename("count").to_frame()
predicate_stats['list'] = df1.groupby(['subject','object'], group_keys=False)['predicate'].unique().apply(list)
predicate_stats = predicate_stats.reset_index()

with pd.option_context('display.min_rows', 20,
                       'display.max_columns', None,
                       'display.precision', 3,
                       ):
    print(predicate_stats)
# Out:
#               subject                    object  count  \
# 0    AnatomicalEntity          AnatomicalEntity     17
# 1    AnatomicalEntity         BiologicalProcess     16
# 2    AnatomicalEntity                      Cell     15
# 3    AnatomicalEntity         CellularComponent      7
# 4    AnatomicalEntity            ChemicalEntity      4
# 5    AnatomicalEntity                   Disease     13
# 6    AnatomicalEntity                      Gene      4
# 7    AnatomicalEntity  GrossAnatomicalStructure     17
# 8    AnatomicalEntity         MolecularActivity      4
# 9    AnatomicalEntity          MolecularMixture      3
# ..                ...                       ...    ...
# 384     SmallMolecule          MolecularMixture      8
# 385     SmallMolecule       PathologicalProcess     10
# 386     SmallMolecule                   Pathway      2
# 387     SmallMolecule         PhenotypicFeature     20
# 388     SmallMolecule      PhysiologicalProcess      8
# 389     SmallMolecule               Polypeptide     16
# 390     SmallMolecule                 Procedure      6
# 391     SmallMolecule                   Protein     12
# 392     SmallMolecule             SmallMolecule     23
# 393         Treatment                   Disease      1
#
#                                                   list
# 0    [subclass_of, superclass_of, has_part, part_of...
# 1    [related_to, regulated_by, is_output_of, parti...
# 2    [has_part, related_to, overlaps, coexists_with...
# 3    [superclass_of, subclass_of, has_part, related...
# 4           [related_to, overlaps, has_part, produces]
# 5    [related_to, affected_by, location_of, caused_...
# 6    [genetic_association, entity_positively_regula...
# 7    [overlaps, related_to, precedes, has_part, loc...
# 8    [contains_process, is_input_of, participates_i...
# 9                     [related_to, overlaps, has_part]
# ..                                                 ...
# 384  [subclass_of, related_to, overlaps, has_part, ...
# 385  [treats, causes, associated_with, prevents, af...
# 386                     [participates_in, is_input_of]
# 387  [affected_by, related_to, treats, causes_adver...
# 388  [causes, disrupts, affects, entity_positively_...
# 389  [subclass_of, superclass_of, related_to, overl...
# 390  [positively_correlated_with, negatively_correl...
# 391  [related_to, overlaps, part_of, subclass_of, i...
# 392  [subclass_of, superclass_of, related_to, overl...
# 393                                       [related_to]
#
# [394 rows x 4 columns]

# %%
predicate_stats.to_csv("results/predicate_stats.tsv", sep="\t", index=False)

# %% [markdown]
# ## Filter by most common types

# %% [markdown]
# Filter to only include the most common types of entities.  Also, since we _mostly_ have the same info in both directions, only keep one direction to simplify visualization

# %%
pd.concat([df_bte['subject'], df_bte['object']]).value_counts().head(20)
# Out:
# Disease                     955
# SmallMolecule               824
# Gene                        805
# ChemicalEntity              629
# PhenotypicFeature           490
# BiologicalProcess           463
# Polypeptide                 463
# MolecularMixture            391
# Protein                     339
# Cell                        339
# CellularComponent           333
# AnatomicalEntity            331
# GrossAnatomicalStructure    316
# MolecularActivity           291
# Pathway                     203
# OrganismTaxon               201
# PathologicalProcess         182
# ChemicalMixture             164
# PhysiologicalProcess        138
# ComplexMolecularMixture     125
# dtype: int64

# %%
NUM_TYPES_TO_KEEP = 10

keep = set(pd.concat([df_bte['subject'], df_bte['object']]).value_counts().head(NUM_TYPES_TO_KEEP).keys())
keep
# Out:
# {'BiologicalProcess',
#  'Cell',
#  'ChemicalEntity',
#  'Disease',
#  'Gene',
#  'MolecularMixture',
#  'PhenotypicFeature',
#  'Polypeptide',
#  'Protein',
#  'SmallMolecule'}

# %%
predicate_stats_filt = predicate_stats.query("subject in @keep & object in @keep & subject <= object")
predicate_stats_filt.to_csv("results/predicate_stats_filt.tsv", sep="\t")
predicate_stats_filt
# Out:
#                subject             object  count  \
# 17   BiologicalProcess  BiologicalProcess     23
# 18   BiologicalProcess               Cell     13
# 20   BiologicalProcess     ChemicalEntity     12
# 23   BiologicalProcess            Disease     16
# 24   BiologicalProcess               Gene      2
# 27   BiologicalProcess   MolecularMixture      7
# 30   BiologicalProcess  PhenotypicFeature      4
# 31   BiologicalProcess        Polypeptide      8
# 32   BiologicalProcess            Protein     20
# 33   BiologicalProcess      SmallMolecule      9
# 36                Cell               Cell     11
# 38                Cell     ChemicalEntity     12
# 39                Cell            Disease     12
# 40                Cell               Gene      8
# 43                Cell   MolecularMixture      2
# 47                Cell  PhenotypicFeature      2
# 49                Cell        Polypeptide      9
# 51                Cell            Protein      4
# 52                Cell      SmallMolecule     14
# 78      ChemicalEntity     ChemicalEntity     15
# 81      ChemicalEntity            Disease     22
# 82      ChemicalEntity               Gene     38
# 85      ChemicalEntity   MolecularMixture      8
# 88      ChemicalEntity  PhenotypicFeature     16
# 90      ChemicalEntity        Polypeptide     14
# 92      ChemicalEntity            Protein      9
# 93      ChemicalEntity      SmallMolecule     15
# 125            Disease            Disease     43
# 128            Disease               Gene     24
# 131            Disease   MolecularMixture     13
# 135            Disease  PhenotypicFeature     25
# 137            Disease        Polypeptide     15
# 139            Disease            Protein      6
# 141            Disease      SmallMolecule     27
# 160               Gene               Gene     31
# 164               Gene   MolecularMixture     32
# 168               Gene  PhenotypicFeature     11
# 170               Gene        Polypeptide     21
# 171               Gene            Protein      4
# 173               Gene      SmallMolecule     57
# 228   MolecularMixture   MolecularMixture      8
# 230   MolecularMixture  PhenotypicFeature     14
# 231   MolecularMixture        Polypeptide      6
# 232   MolecularMixture            Protein      3
# 233   MolecularMixture      SmallMolecule      8
# 294  PhenotypicFeature  PhenotypicFeature     21
# 296  PhenotypicFeature        Polypeptide     13
# 298  PhenotypicFeature            Protein      2
# 300  PhenotypicFeature      SmallMolecule     20
# 331        Polypeptide        Polypeptide     16
# 333        Polypeptide            Protein      8
# 334        Polypeptide      SmallMolecule     16
# 366            Protein            Protein     10
# 367            Protein      SmallMolecule     14
# 392      SmallMolecule      SmallMolecule     23
#
#                                                   list
# 17   [subclass_of, superclass_of, causes, caused_by...
# 18   [related_to, has_participant, regulates, occur...
# 20   [has_input, has_participant, has_output, affec...
# 23   [causes, has_participant, subclass_of, related...
# 24                         [has_part, has_participant]
# 27   [affects_transport_of, related_to, has_partici...
# 30   [affected_by, related_to, superclass_of, has_r...
# 31   [has_participant, related_to, affects_transpor...
# 32   [is_output_of, caused_by, related_to, has_capa...
# 33   [has_input, has_participant, has_output, affec...
# 36   [subclass_of, superclass_of, related_to, devel...
# 38   [expresses, related_to, overlaps, has_part, ha...
# 39   [related_to, affected_by, location_of, caused_...
# 40   [genetic_association, interacts_with, has_part...
# 43                  [has_biomarker, contribution_from]
# 47                           [affected_by, related_to]
# 49   [related_to, overlaps, has_part, location_of, ...
# 51         [expresses, related_to, overlaps, has_part]
# 52   [related_to, overlaps, has_part, has_biomarker...
# 78   [subclass_of, superclass_of, related_to, overl...
# 81   [causes, caused_by, affected_by, related_to, p...
# 82   [correlated_with, directly_interacts_with, act...
# 85   [subclass_of, related_to, overlaps, has_part, ...
# 88   [related_to, affected_by, superclass_of, cause...
# 90   [superclass_of, subclass_of, related_to, overl...
# 92   [superclass_of, related_to, overlaps, part_of,...
# 93   [superclass_of, related_to, overlaps, part_of,...
# 125  [superclass_of, subclass_of, has_phenotype, ph...
# 128  [related_to, causes, disrupts, has_participant...
# 131  [affects, caused_by, causes, treated_by, has_c...
# 135  [related_to, has_phenotype, subclass_of, corre...
# 137  [affects, treated_by, has_biomarker, contribut...
# 139  [caused_by, affects, causes, related_to, produ...
# 141  [caused_by, affects, causes, has_participant, ...
# 160  [subclass_of, superclass_of, interacts_with, o...
# 164  [activity_decreased_by, activity_increased_by,...
# 168  [has_phenotype, genetic_association, related_t...
# 170  [response_decreased_by, increases_uptake_of, a...
# 171  [entity_negatively_regulated_by_entity, intera...
# 173  [correlated_with, activity_decreased_by, activ...
# 228  [subclass_of, superclass_of, related_to, overl...
# 230  [affected_by, related_to, superclass_of, treat...
# 231  [superclass_of, related_to, overlaps, has_part...
# 232  [subclass_of, interacts_with, increases_transp...
# 233  [superclass_of, related_to, overlaps, part_of,...
# 294  [subclass_of, superclass_of, has_part, part_of...
# 296  [treated_by, has_biomarker, related_to, affect...
# 298                              [related_to, affects]
# 300  [treated_by, has_contraindication, has_biomark...
# 331  [subclass_of, superclass_of, related_to, overl...
# 333  [related_to, overlaps, part_of, subclass_of, i...
# 334  [superclass_of, subclass_of, related_to, overl...
# 366  [subclass_of, superclass_of, derives_from, der...
# 367  [related_to, overlaps, has_part, superclass_of...
# 392  [subclass_of, superclass_of, related_to, overl...

# %%
api_stats_filt = api_stats.query("subject in @keep & object in @keep & subject <= object")
api_stats_filt.to_csv("results/api_stats_filt.tsv", sep="\t")
api_stats_filt
# Out:
#                subject             object  count  \
# 17   BiologicalProcess  BiologicalProcess      8
# 18   BiologicalProcess               Cell      1
# 20   BiologicalProcess     ChemicalEntity      2
# 23   BiologicalProcess            Disease     10
# 24   BiologicalProcess               Gene      2
# 27   BiologicalProcess   MolecularMixture      2
# 30   BiologicalProcess  PhenotypicFeature      7
# 31   BiologicalProcess        Polypeptide      1
# 32   BiologicalProcess            Protein      3
# 33   BiologicalProcess      SmallMolecule      2
# 36                Cell               Cell      4
# 38                Cell     ChemicalEntity      4
# 39                Cell            Disease      6
# 40                Cell               Gene      2
# 43                Cell   MolecularMixture      2
# 47                Cell  PhenotypicFeature      1
# 49                Cell        Polypeptide      2
# 51                Cell            Protein      1
# 52                Cell      SmallMolecule      4
# 78      ChemicalEntity     ChemicalEntity     10
# 81      ChemicalEntity            Disease      8
# 82      ChemicalEntity               Gene      5
# 85      ChemicalEntity   MolecularMixture     10
# 88      ChemicalEntity  PhenotypicFeature      8
# 90      ChemicalEntity        Polypeptide      6
# 92      ChemicalEntity            Protein     10
# 93      ChemicalEntity      SmallMolecule     11
# 125            Disease            Disease     14
# 128            Disease               Gene     16
# 131            Disease   MolecularMixture      7
# 135            Disease  PhenotypicFeature     14
# 137            Disease        Polypeptide      4
# 139            Disease            Protein      2
# 141            Disease      SmallMolecule     16
# 160               Gene               Gene     18
# 164               Gene   MolecularMixture      3
# 168               Gene  PhenotypicFeature      7
# 170               Gene        Polypeptide      2
# 171               Gene            Protein      1
# 173               Gene      SmallMolecule     12
# 228   MolecularMixture   MolecularMixture     10
# 230   MolecularMixture  PhenotypicFeature      7
# 231   MolecularMixture        Polypeptide      7
# 232   MolecularMixture            Protein      4
# 233   MolecularMixture      SmallMolecule     10
# 294  PhenotypicFeature  PhenotypicFeature     12
# 296  PhenotypicFeature        Polypeptide      4
# 298  PhenotypicFeature            Protein      1
# 300  PhenotypicFeature      SmallMolecule     11
# 331        Polypeptide        Polypeptide      5
# 333        Polypeptide            Protein      3
# 334        Polypeptide      SmallMolecule     10
# 366            Protein            Protein      9
# 367            Protein      SmallMolecule      5
# 392      SmallMolecule      SmallMolecule     15
#
#                                                   list
# 17   [Automat-uberongraph(Trapi v1.3.0), Automat-bi...
# 18                 [Automat-uberongraph(Trapi v1.3.0)]
# 20   [Automat-uberongraph(Trapi v1.3.0), Automat-ic...
# 23   [Automat-uberongraph(Trapi v1.3.0), Automat-dr...
# 24      [Automat-hetio(Trapi v1.3.0), MyGene.info API]
# 27   [Automat-uberongraph(Trapi v1.3.0), Automat-ic...
# 30   [Automat-uberongraph(Trapi v1.3.0), Automat-bi...
# 31                 [Automat-uberongraph(Trapi v1.3.0)]
# 32   [Automat-uberongraph(Trapi v1.3.0), Automat-hu...
# 33   [Automat-uberongraph(Trapi v1.3.0), Automat-ic...
# 36   [Automat-uberongraph(Trapi v1.3.0), Automat-bi...
# 38   [Automat-uberongraph(Trapi v1.3.0), Automat-bi...
# 39   [Automat-uberongraph(Trapi v1.3.0), Automat-bi...
# 40   [Automat-pharos(Trapi v1.3.0), BioThings SEMME...
# 43   [Automat-biolink(Trapi v1.3.0), Automat-ctd(Tr...
# 47                 [Automat-uberongraph(Trapi v1.3.0)]
# 49   [Automat-uberongraph(Trapi v1.3.0), BioThings ...
# 51                 [Automat-uberongraph(Trapi v1.3.0)]
# 52   [Automat-uberongraph(Trapi v1.3.0), Automat-bi...
# 78   [Automat-uberongraph(Trapi v1.3.0), Automat-dr...
# 81   [Automat-uberongraph(Trapi v1.3.0), Automat-dr...
# 82   [Automat-hmdb(Trapi v1.3.0), Automat-pharos(Tr...
# 85   [Automat-uberongraph(Trapi v1.3.0), Automat-dr...
# 88   [Automat-uberongraph(Trapi v1.3.0), Automat-dr...
# 90   [Automat-uberongraph(Trapi v1.3.0), Automat-bi...
# 92   [Automat-uberongraph(Trapi v1.3.0), Automat-dr...
# 93   [Automat-uberongraph(Trapi v1.3.0), Automat-dr...
# 125  [Ontology Lookup Service API, Automat-uberongr...
# 128  [Automat-uberongraph(Trapi v1.3.0), Automat-bi...
# 131  [Automat-uberongraph(Trapi v1.3.0), Automat-dr...
# 135  [Automat-uberongraph(Trapi v1.3.0), Automat-dr...
# 137  [Automat-uberongraph(Trapi v1.3.0), Automat-bi...
# 139  [Automat-uberongraph(Trapi v1.3.0), BioThings ...
# 141  [Automat-uberongraph(Trapi v1.3.0), Automat-dr...
# 160  [Automat-hgnc(Trapi v1.3.0), Automat-hmdb(Trap...
# 164  [Automat-gtopdb(Trapi v1.3.0), Automat-pharos(...
# 168  [Automat-biolink(Trapi v1.3.0), Automat-pharos...
# 170  [Automat-ctd(Trapi v1.3.0), BioThings SEMMEDDB...
# 171                           [BioThings SEMMEDDB API]
# 173  [Automat-hmdb(Trapi v1.3.0), Automat-gtopdb(Tr...
# 228  [Automat-uberongraph(Trapi v1.3.0), Automat-dr...
# 230  [Automat-uberongraph(Trapi v1.3.0), Automat-dr...
# 231  [Automat-uberongraph(Trapi v1.3.0), Automat-dr...
# 232  [Automat-uberongraph(Trapi v1.3.0), Automat-dr...
# 233  [Automat-uberongraph(Trapi v1.3.0), Automat-dr...
# 294  [Automat-drug-central(Trapi v1.3.0), Automat-b...
# 296  [Automat-biolink(Trapi v1.3.0), Automat-uberon...
# 298                [Automat-uberongraph(Trapi v1.3.0)]
# 300  [Automat-drug-central(Trapi v1.3.0), Automat-b...
# 331  [Automat-uberongraph(Trapi v1.3.0), Automat-bi...
# 333  [Automat-uberongraph(Trapi v1.3.0), Automat-on...
# 334  [Automat-uberongraph(Trapi v1.3.0), Automat-dr...
# 366  [Automat-uberongraph(Trapi v1.3.0), Automat-dr...
# 367  [Automat-uberongraph(Trapi v1.3.0), Automat-hm...
# 392  [Automat-uberongraph(Trapi v1.3.0), Automat-dr...

# %% [markdown]
# ## Export to graphml

# %%
def create_graph(df2, filename):
    G = nx.Graph()

    node_types = set(pd.concat([df2['subject'], df2['object']]))
        
    for node_type in node_types:
        G.add_node(node_type, label = add_spacing(node_type))

    for index,row in df2.iterrows():
        G.add_edge(row['subject'], row['object'], weight=row['count'])
    
    nx.write_graphml(G, filename, infer_numeric_types=True)

# %%
def add_spacing(str):
    key = {
        "BiologicalProcess":               "Biological\nProcess",
        "ChemicalEntity":                  "Chemical\nEntity",
        "MolecularMixture":                "Molecular\nMixture", 
        "PhysiologicalProcess":            "Physiological\nProcess",
        "SmallMolecule":                   "Small\nMolecule",
        "PhenotypicFeature":               "Phenotypic\nFeature",
        'ChemicalExposure':                'Chemical\nExposure',
        'ClinicalAttribute':               'Clinical\nAttribute',
        'ClinicalIntervention':            'Clinical\nIntervention',
        'ComplexMolecularMixture':         'Complex\nMolecular\nMixture',
        'EnvironmentalExposure':           'Environmental\nExposure',
        'InformationContentEntity':        'Information\nContentEntity',
        'MolecularMixture':                'Molecular\nMixture',
        'PhysiologicalProcess':            'Physiological\nProcess',
        'PopulationOfIndividualOrganisms': 'PopulationOf\nIndividualOrganisms'
    }
    if str in key.keys():
        return(key[str])
    else:
        return(str)

# %%
create_graph(api_stats_filt, "results/api_stats_filt.graphml")
create_graph(predicate_stats_filt, "results/predicate_stats_filt.graphml")

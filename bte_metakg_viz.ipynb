# %% [markdown]
# # BTE metakg visualization
#
# The goal of this notebook is to visualize the metaKG that BTE uses.  Similar to the [subway diagram](https://raw.githubusercontent.com/biothings/BioThings_Explorer_TRAPI/main/diagrams/smartapi_metagraph.png) we've used before, but updated to the size and scale of the current metakg.
#
# This notebook takes as input an ndson file with the SmartAPI metakg (originally provided by Chunlei on 2023-03-01).
#
# Optimizations
# * remove less-commonly-used node types from subject/object
# * only count in one direction (`A-treats-B` gets merged with `B-treated_by-A`)

# %%
import json5
import networkx as nx
import pandas as pd
import re
import requests

# %% [markdown]
# ## Read in data
#
# First, read in the Smart API ndjson file

# %%
df = pd.read_json('data/smartapi_metakg_03012023.ndjson.gz', lines=True)
df
# Out:
#                  subject             object  \
# 0       AnatomicalEntity  MolecularActivity
# 1       AnatomicalEntity    MolecularEntity
# 2       AnatomicalEntity         NamedThing
# 3       AnatomicalEntity  NucleicAcidEntity
# 4       AnatomicalEntity          Occurrent
# ...                  ...                ...
# 175543              Cell         Phenomenon
# 175544        Transcript           CellLine
# 175545           Disease  PhenotypicFeature
# 175546            Device            Vitamin
# 175547         Procedure          Procedure
#
#                                  predicate  \
# 0                      affects_activity_of
# 1                      affects_activity_of
# 2                      affects_activity_of
# 3                      affects_activity_of
# 4                      affects_activity_of
# ...                                    ...
# 175543                              causes
# 175544           physically_interacts_with
# 175545  entity_positively_regulates_entity
# 175546  entity_negatively_regulates_entity
# 175547                     has_participant
#
#                                                       api provided_by
# 0       {'name': 'CAM-KP API', 'smartapi': {'metadata'...         NaN
# 1       {'name': 'CAM-KP API', 'smartapi': {'metadata'...         NaN
# 2       {'name': 'CAM-KP API', 'smartapi': {'metadata'...         NaN
# 3       {'name': 'CAM-KP API', 'smartapi': {'metadata'...         NaN
# 4       {'name': 'CAM-KP API', 'smartapi': {'metadata'...         NaN
# ...                                                   ...         ...
# 175543  {'name': 'ARAX Translator Reasoner - TRAPI 1.3...         NaN
# 175544  {'name': 'ARAX Translator Reasoner - TRAPI 1.3...         NaN
# 175545  {'name': 'ARAX Translator Reasoner - TRAPI 1.3...         NaN
# 175546  {'name': 'ARAX Translator Reasoner - TRAPI 1.3...         NaN
# 175547  {'name': 'ARAX Translator Reasoner - TRAPI 1.3...         NaN
#
# [175548 rows x 5 columns]

# %% [markdown]
# parse out a couple lines for the API name and ID

# %%
df = df.assign(api_name = lambda x: pd.json_normalize(x['api'])['name'])
df = df.assign(api_id = lambda x: pd.json_normalize(x['api'])['smartapi.id'])
df
# Out:
#                  subject             object  \
# 0       AnatomicalEntity  MolecularActivity
# 1       AnatomicalEntity    MolecularEntity
# 2       AnatomicalEntity         NamedThing
# 3       AnatomicalEntity  NucleicAcidEntity
# 4       AnatomicalEntity          Occurrent
# ...                  ...                ...
# 175543              Cell         Phenomenon
# 175544        Transcript           CellLine
# 175545           Disease  PhenotypicFeature
# 175546            Device            Vitamin
# 175547         Procedure          Procedure
#
#                                  predicate  \
# 0                      affects_activity_of
# 1                      affects_activity_of
# 2                      affects_activity_of
# 3                      affects_activity_of
# 4                      affects_activity_of
# ...                                    ...
# 175543                              causes
# 175544           physically_interacts_with
# 175545  entity_positively_regulates_entity
# 175546  entity_negatively_regulates_entity
# 175547                     has_participant
#
#                                                       api provided_by  \
# 0       {'name': 'CAM-KP API', 'smartapi': {'metadata'...         NaN
# 1       {'name': 'CAM-KP API', 'smartapi': {'metadata'...         NaN
# 2       {'name': 'CAM-KP API', 'smartapi': {'metadata'...         NaN
# 3       {'name': 'CAM-KP API', 'smartapi': {'metadata'...         NaN
# 4       {'name': 'CAM-KP API', 'smartapi': {'metadata'...         NaN
# ...                                                   ...         ...
# 175543  {'name': 'ARAX Translator Reasoner - TRAPI 1.3...         NaN
# 175544  {'name': 'ARAX Translator Reasoner - TRAPI 1.3...         NaN
# 175545  {'name': 'ARAX Translator Reasoner - TRAPI 1.3...         NaN
# 175546  {'name': 'ARAX Translator Reasoner - TRAPI 1.3...         NaN
# 175547  {'name': 'ARAX Translator Reasoner - TRAPI 1.3...         NaN
#
#                                       api_name  \
# 0                                   CAM-KP API
# 1                                   CAM-KP API
# 2                                   CAM-KP API
# 3                                   CAM-KP API
# 4                                   CAM-KP API
# ...                                        ...
# 175543  ARAX Translator Reasoner - TRAPI 1.3.0
# 175544  ARAX Translator Reasoner - TRAPI 1.3.0
# 175545  ARAX Translator Reasoner - TRAPI 1.3.0
# 175546  ARAX Translator Reasoner - TRAPI 1.3.0
# 175547  ARAX Translator Reasoner - TRAPI 1.3.0
#
#                                   api_id
# 0       c409da43f5177ae52392e2b346dbc585
# 1       c409da43f5177ae52392e2b346dbc585
# 2       c409da43f5177ae52392e2b346dbc585
# 3       c409da43f5177ae52392e2b346dbc585
# 4       c409da43f5177ae52392e2b346dbc585
# ...                                  ...
# 175543  e248aefca0f469229e82cca80fbabc89
# 175544  e248aefca0f469229e82cca80fbabc89
# 175545  e248aefca0f469229e82cca80fbabc89
# 175546  e248aefca0f469229e82cca80fbabc89
# 175547  e248aefca0f469229e82cca80fbabc89
#
# [175548 rows x 7 columns]

# %% [markdown]
# Read in the BTE config file that specifies currently-allowed APIs

# %%
bte_config_url = "https://raw.githubusercontent.com/biothings/BioThings_Explorer_TRAPI/main/src/config/apis.js"
r = requests.get(bte_config_url)
str_bte_config = r.text
#print(str_bte_config)
str_bte_config = re.sub("exports.API_LIST = ",  "", str_bte_config)                       # remove variable assignment step
str_bte_config = re.sub("\s*//.*",              "", str_bte_config)                       # remove commented lines
str_bte_config = re.sub(r'^$\n',                '', str_bte_config, flags=re.MULTILINE)   # remove blank lines
str_bte_config = re.sub(r',\s*exclude:[^\]]*]', '', str_bte_config, flags=re.MULTILINE)   # remove 'exclude' section
str_bte_config = re.sub(r';$',                  '', str_bte_config, flags=re.MULTILINE)   # remove 'exclude' section
#print(str_bte_config)

bte_config = json5.loads(str_bte_config)
bte_config
# Out:
# {'include': [{'id': 'd22b657426375a5295e7da8a303b9893', 'name': 'BioLink API'},
#   {'id': '43af91b3d7cae43591083bff9d75c6dd', 'name': 'EBI Proteins API'},
#   {'id': 'dca415f2d792976af9d642b7e73f7a41', 'name': 'LitVar API'},
#   {'id': '1f277e1563fcfd124bfae2cc3c4bcdec', 'name': 'QuickGO API'},
#   {'id': '1c056ffc7ed0dd1229e71c4752239465',
#    'name': 'Ontology Lookup Service API'},
#   {'id': '38e9e5169a72aee3659c9ddba956790d',
#    'name': 'BioThings BindingDB API'},
#   {'id': '55a223c6c6e0291dbd05f2faf27d16f4',
#    'name': 'BioThings BioPlanet Pathway-Disease API'},
#   {'id': 'b99c6dd64abcefe87dcd0a51c249ee6d',
#    'name': 'BioThings BioPlanet Pathway-Gene API'},
#   {'id': '00fb85fc776279163199e6c50f6ddfc6', 'name': 'BioThings DDInter API'},
#   {'id': 'e3edd325c76f2992a111b43a907a4870', 'name': 'BioThings DGIdb API'},
#   {'id': 'a7f784626a426d054885a5f33f17d3f8', 'name': 'BioThings DISEASES API'},
#   {'id': '1f47552dabd67351d4c625adb0a10d00',
#    'name': 'BioThings EBIgene2phenotype API'},
#   {'id': 'cc857d5b7c8b7609b5bbb38ff990bfff',
#    'name': 'BioThings GO Biological Process API'},
#   {'id': 'f339b28426e7bf72028f60feefcd7465',
#    'name': 'BioThings GO Cellular Component API'},
#   {'id': '34bad236d77bea0a0ee6c6cba5be54a6',
#    'name': 'BioThings GO Molecular Function API'},
#   {'id': '316eab811fd9ef1097df98bcaa9f7361', 'name': 'BioThings GTRx API'},
#   {'id': 'a5b0ec6bfde5008984d4b6cde402d61f', 'name': 'BioThings HPO API'},
#   {'id': '32f36164fabed5d3abe6c2fd899c9418', 'name': 'BioThings IDISK API'},
#   {'id': '77ed27f111262d0289ed4f4071faa619',
#    'name': 'BioThings MGIgene2phenotype API'},
#   {'id': 'edeb26858bd27d0322af93e7a9e08761', 'name': 'BioThings PFOCR API'},
#   {'id': '03283cc2b21c077be6794e1704b1d230', 'name': 'BioThings Rhea API'},
#   {'id': '1d288b3a3caf75d541ffaae3aab386c8', 'name': 'BioThings SEMMEDDB API'},
#   {'id': 'ec6d76016ef40f284359d17fbf78df20', 'name': 'BioThings UBERON API'},
#   {'id': '8f08d1446e0bb9c2b323713ce83e2bd3', 'name': 'MyChem.info API'},
#   {'id': '671b45c0301c8624abbd26ae78449ca2', 'name': 'MyDisease.info API'},
#   {'id': '59dce17363dce279d389100834e43648', 'name': 'MyGene.info API'},
#   {'id': '09c8782d9f4027712e65b95424adba79', 'name': 'MyVariant.info API'},
#   {'id': 'adf20dd6ff23dfe18e8e012bde686e31',
#    'name': 'Multiomics BigGIM-DrugResponse KP API'},
#   {'id': '08a5ddcde71b4bf838327ef469076acd',
#    'name': 'Multiomics ClinicalTrials KP'},
#   {'id': 'd86a24f6027ffe778f84ba10a7a1861a',
#    'name': 'Multiomics EHR Risk KP API'},
#   {'id': '02af7d098ab304e80d6f4806c3527027',
#    'name': 'Multiomics Wellness KP API'},
#   {'id': '978fe380a147a8641caf72320862697b',
#    'name': 'Text Mining Targeted Association API'},
#   {'id': '25085b05fd1afcebb497724d147cfb44',
#    'name': 'Automat-biolink(Trapi v1.3.0)'},
#   {'id': '89aa98098ba4329aa49b43ff8d21ffbb',
#    'name': 'Automat-ctd(Trapi v1.3.0)'},
#   {'id': '463525b319d7e1ef8f705bce953d01bd',
#    'name': 'Automat-cord19(Trapi v1.3.0)'},
#   {'id': '539873b1f2f2eb913efaee411e09eaa7',
#    'name': 'Automat-drug-central(Trapi v1.3.0)'},
#   {'id': '272c2357763e4faf737f1cba94beaa1d',
#    'name': 'Automat-gtex(Trapi v1.3.0)'},
#   {'id': 'fb1f3780ad67b030cb0617363afa8f61',
#    'name': 'Automat-gwas-catalog(Trapi v1.3.0)'},
#   {'id': 'aacdd9e863bb659574d302f084084976',
#    'name': 'Automat-gtopdb(Trapi v1.3.0)'},
#   {'id': '7382f0fabffce3cc7f7b8b6358c69259',
#    'name': 'Automat-hgnc(Trapi v1.3.0)'},
#   {'id': 'ee2d2eae42ca30fe82946d3f42febaa0',
#    'name': 'Automat-hmdb(Trapi v1.3.0)'},
#   {'id': '830600da121a5accc955cbf62e60f802',
#    'name': 'Automat-hetio(Trapi v1.3.0)'},
#   {'id': 'f30339a6894a146a19a34974712ca2e3',
#    'name': 'Automat-human-goa(Trapi v1.3.0)'},
#   {'id': '44e7a1147ca8657f50af6bb25982762d',
#    'name': 'Automat-icees-kg(Trapi v1.3.0)'},
#   {'id': 'e0687431a9ff88344d20e83e0c99ee7d',
#    'name': 'Automat-intact(Trapi v1.3.0)'},
#   {'id': '4c6f9117581531161849e60ea906f0be',
#    'name': 'Automat-ontology-hierarchy(Trapi v1.3.0)'},
#   {'id': '2a879882329b000c7e7f08c2d71ccffd',
#    'name': 'Automat-panther(Trapi v1.3.0)'},
#   {'id': '0295640b4d060133e4296dda4c31da47',
#    'name': 'Automat-pharos(Trapi v1.3.0)'},
#   {'id': 'ef9027a7d2246c6540cc7b3ce202d89f',
#    'name': 'Automat-uberongraph(Trapi v1.3.0)'},
#   {'id': '79310edd01cae96f3d8495250e625886',
#    'name': 'Automat-viral-proteome(Trapi v1.3.0)'},
#   {'id': '51c178099fa2dc99b5d8fff8bf9f1a0d', 'name': 'COHD TRAPI 1.3'},
#   {'id': '855adaa128ce5aa58a091d99e520d396',
#    'name': 'Connections Hypothesis Provider API'}]}

# %%
bte_config_ids = [ x['id'] for x in bte_config['include'] ]
bte_config_ids
# Out:
# ['d22b657426375a5295e7da8a303b9893',
#  '43af91b3d7cae43591083bff9d75c6dd',
#  'dca415f2d792976af9d642b7e73f7a41',
#  '1f277e1563fcfd124bfae2cc3c4bcdec',
#  '1c056ffc7ed0dd1229e71c4752239465',
#  '38e9e5169a72aee3659c9ddba956790d',
#  '55a223c6c6e0291dbd05f2faf27d16f4',
#  'b99c6dd64abcefe87dcd0a51c249ee6d',
#  '00fb85fc776279163199e6c50f6ddfc6',
#  'e3edd325c76f2992a111b43a907a4870',
#  'a7f784626a426d054885a5f33f17d3f8',
#  '1f47552dabd67351d4c625adb0a10d00',
#  'cc857d5b7c8b7609b5bbb38ff990bfff',
#  'f339b28426e7bf72028f60feefcd7465',
#  '34bad236d77bea0a0ee6c6cba5be54a6',
#  '316eab811fd9ef1097df98bcaa9f7361',
#  'a5b0ec6bfde5008984d4b6cde402d61f',
#  '32f36164fabed5d3abe6c2fd899c9418',
#  '77ed27f111262d0289ed4f4071faa619',
#  'edeb26858bd27d0322af93e7a9e08761',
#  '03283cc2b21c077be6794e1704b1d230',
#  '1d288b3a3caf75d541ffaae3aab386c8',
#  'ec6d76016ef40f284359d17fbf78df20',
#  '8f08d1446e0bb9c2b323713ce83e2bd3',
#  '671b45c0301c8624abbd26ae78449ca2',
#  '59dce17363dce279d389100834e43648',
#  '09c8782d9f4027712e65b95424adba79',
#  'adf20dd6ff23dfe18e8e012bde686e31',
#  '08a5ddcde71b4bf838327ef469076acd',
#  'd86a24f6027ffe778f84ba10a7a1861a',
#  '02af7d098ab304e80d6f4806c3527027',
#  '978fe380a147a8641caf72320862697b',
#  '25085b05fd1afcebb497724d147cfb44',
#  '89aa98098ba4329aa49b43ff8d21ffbb',
#  '463525b319d7e1ef8f705bce953d01bd',
#  '539873b1f2f2eb913efaee411e09eaa7',
#  '272c2357763e4faf737f1cba94beaa1d',
#  'fb1f3780ad67b030cb0617363afa8f61',
#  'aacdd9e863bb659574d302f084084976',
#  '7382f0fabffce3cc7f7b8b6358c69259',
#  'ee2d2eae42ca30fe82946d3f42febaa0',
#  '830600da121a5accc955cbf62e60f802',
#  'f30339a6894a146a19a34974712ca2e3',
#  '44e7a1147ca8657f50af6bb25982762d',
#  'e0687431a9ff88344d20e83e0c99ee7d',
#  '4c6f9117581531161849e60ea906f0be',
#  '2a879882329b000c7e7f08c2d71ccffd',
#  '0295640b4d060133e4296dda4c31da47',
#  'ef9027a7d2246c6540cc7b3ce202d89f',
#  '79310edd01cae96f3d8495250e625886',
#  '51c178099fa2dc99b5d8fff8bf9f1a0d',
#  '855adaa128ce5aa58a091d99e520d396']

# %% [markdown]
# ## Join SmartAPI data with BTE config IDs

# %%
df_bte = df.query('api_id in @bte_config_ids')
df_bte
# Out:
#                   subject         object               predicate  \
# 3000      SequenceVariant           Gene  is_sequence_variant_of
# 5115                 Gene           Gene          orthologous_to
# 5116                 Gene           Gene           superclass_of
# 5117                 Gene           Gene           biomarker_for
# 5118                 Gene           Gene            phenotype_of
# ...                   ...            ...                     ...
# 130260  PhenotypicFeature  SmallMolecule       contribution_from
# 130261      SmallMolecule        Disease          contributes_to
# 130262            Disease  SmallMolecule       contribution_from
# 130263      SmallMolecule        Disease          contributes_to
# 130264            Disease  SmallMolecule       contribution_from
#
#                                                       api    provided_by  \
# 3000    {'name': 'LitVar API', 'smartapi': {'metadata'...  infores:dbsnp
# 5115    {'name': 'Automat-biolink(Trapi v1.3.0)', 'sma...            NaN
# 5116    {'name': 'Automat-biolink(Trapi v1.3.0)', 'sma...            NaN
# 5117    {'name': 'Automat-biolink(Trapi v1.3.0)', 'sma...            NaN
# 5118    {'name': 'Automat-biolink(Trapi v1.3.0)', 'sma...            NaN
# ...                                                   ...            ...
# 130260  {'name': 'Text Mining Targeted Association API...            NaN
# 130261  {'name': 'Text Mining Targeted Association API...            NaN
# 130262  {'name': 'Text Mining Targeted Association API...            NaN
# 130263  {'name': 'Text Mining Targeted Association API...            NaN
# 130264  {'name': 'Text Mining Targeted Association API...            NaN
#
#                                     api_name                            api_id
# 3000                              LitVar API  dca415f2d792976af9d642b7e73f7a41
# 5115           Automat-biolink(Trapi v1.3.0)  25085b05fd1afcebb497724d147cfb44
# 5116           Automat-biolink(Trapi v1.3.0)  25085b05fd1afcebb497724d147cfb44
# 5117           Automat-biolink(Trapi v1.3.0)  25085b05fd1afcebb497724d147cfb44
# 5118           Automat-biolink(Trapi v1.3.0)  25085b05fd1afcebb497724d147cfb44
# ...                                      ...                               ...
# 130260  Text Mining Targeted Association API  978fe380a147a8641caf72320862697b
# 130261  Text Mining Targeted Association API  978fe380a147a8641caf72320862697b
# 130262  Text Mining Targeted Association API  978fe380a147a8641caf72320862697b
# 130263  Text Mining Targeted Association API  978fe380a147a8641caf72320862697b
# 130264  Text Mining Targeted Association API  978fe380a147a8641caf72320862697b
#
# [4781 rows x 7 columns]

# %%
df_bte.to_csv("results/bte_operations.tsv", sep="\t")

# %%
df_bte['api_name'].value_counts()
# Out:
# BioThings SEMMEDDB API                     2497
# Automat-icees-kg(Trapi v1.3.0)              454
# Automat-ctd(Trapi v1.3.0)                   441
# Multiomics EHR Risk KP API                  204
# Multiomics Wellness KP API                  196
# Automat-hetio(Trapi v1.3.0)                 190
# Automat-biolink(Trapi v1.3.0)               134
# Automat-pharos(Trapi v1.3.0)                 99
# Automat-hmdb(Trapi v1.3.0)                   66
# Automat-human-goa(Trapi v1.3.0)              58
# COHD TRAPI 1.3                               50
# Automat-gtopdb(Trapi v1.3.0)                 42
# Automat-viral-proteome(Trapi v1.3.0)         35
# Automat-panther(Trapi v1.3.0)                34
# Text Mining Targeted Association API         32
# MyDisease.info API                           26
# BioThings DGIdb API                          24
# MyChem.info API                              20
# BioLink API                                  19
# Multiomics BigGIM-DrugResponse KP API        18
# MyGene.info API                              18
# UBERON Ontology API                          16
# MyVariant.info API                           16
# Connections Hypothesis Provider API          12
# Automat-intact(Trapi v1.3.0)                 11
# Gene Ontology Biological Process API         10
# BioThings iDISK API                           8
# BioThings pfocr API                           6
# BioThings Rhea API                            5
# MGIgene2phenotype API                         4
# Gene Ontology Cellular Component API          4
# EBIgene2phenotype API                         4
# Gene Ontology Molecular Activity API          4
# Automat-hgnc(Trapi v1.3.0)                    4
# BioThings BioPlanet Pathway-Disease API       2
# Multiomics ClinicalTrials KP                  2
# BioThings GTRx API                            2
# BioThings BioPlanet Pathway-Gene API          2
# BioThings BindingDB API                       2
# BioThings DDInter API                         2
# Human Phenotype Ontology API                  2
# DISEASES API                                  2
# QuickGO API                                   1
# Ontology Lookup Service API                   1
# EBI Proteins API                              1
# LitVar API                                    1
# Name: api_name, dtype: int64

# %% [markdown]
# ## Summarization

# %% [markdown]
# ### by subject, object; count # of APIs

# %%
df1 = df_bte[["subject","object","api_name"]]
api_stats = df1.groupby(['subject','object'], group_keys=False)['api_name'].nunique().rename("count").to_frame()
api_stats['list'] = df1.groupby(['subject','object'], group_keys=False)['api_name'].unique().apply(list)
api_stats = api_stats.reset_index()

with pd.option_context('display.min_rows', 20,
                       'display.max_columns', None,
                       'display.precision', 3,
                       ):
    print(api_stats)
# Out:
#            subject                           object  count  \
# 0         Activity                         Activity      1
# 1         Activity                       Annotation      1
# 2         Activity                BiologicalProcess      1
# 3         Activity                   ChemicalEntity      1
# 4         Activity                 ChemicalExposure      1
# 5         Activity                ClinicalAttribute      1
# 6         Activity             ClinicalIntervention      1
# 7         Activity          ComplexMolecularMixture      1
# 8         Activity                           Device      1
# 9         Activity                          Disease      1
# ..             ...                              ...    ...
# 672  SmallMolecule                       Phenomenon      1
# 673  SmallMolecule                PhenotypicFeature      9
# 674  SmallMolecule             PhysiologicalProcess      3
# 675  SmallMolecule                      Polypeptide      7
# 676  SmallMolecule  PopulationOfIndividualOrganisms      1
# 677  SmallMolecule                        Procedure      5
# 678  SmallMolecule                          Protein      7
# 679  SmallMolecule                      Publication      1
# 680  SmallMolecule                    SmallMolecule     12
# 681      Treatment                          Disease      1
#
#                                                   list
# 0                     [Automat-icees-kg(Trapi v1.3.0)]
# 1                     [Automat-icees-kg(Trapi v1.3.0)]
# 2                     [Automat-icees-kg(Trapi v1.3.0)]
# 3                     [Automat-icees-kg(Trapi v1.3.0)]
# 4                     [Automat-icees-kg(Trapi v1.3.0)]
# 5                     [Automat-icees-kg(Trapi v1.3.0)]
# 6                     [Automat-icees-kg(Trapi v1.3.0)]
# 7                     [Automat-icees-kg(Trapi v1.3.0)]
# 8                     [Automat-icees-kg(Trapi v1.3.0)]
# 9                     [Automat-icees-kg(Trapi v1.3.0)]
# ..                                                 ...
# 672                      [Automat-hetio(Trapi v1.3.0)]
# 673  [Automat-biolink(Trapi v1.3.0), Automat-icees-...
# 674  [Automat-icees-kg(Trapi v1.3.0), Automat-hetio...
# 675  [Automat-biolink(Trapi v1.3.0), Automat-hetio(...
# 676                   [Automat-icees-kg(Trapi v1.3.0)]
# 677  [Automat-icees-kg(Trapi v1.3.0), Automat-hetio...
# 678  [Automat-biolink(Trapi v1.3.0), Automat-icees-...
# 679                   [Automat-icees-kg(Trapi v1.3.0)]
# 680  [Automat-biolink(Trapi v1.3.0), Automat-icees-...
# 681                     [Multiomics ClinicalTrials KP]
#
# [682 rows x 4 columns]

# %%
api_stats.to_csv("results/api_stats.tsv", sep="\t")

# %% [markdown]
# ### by subject, object; count # of predicates

# %%
df1 = df_bte[["subject","object","predicate"]]
predicate_stats = df1.groupby(['subject','object'], group_keys=False)['predicate'].nunique().rename("count").to_frame()
predicate_stats['list'] = df1.groupby(['subject','object'], group_keys=False)['predicate'].unique().apply(list)
predicate_stats = predicate_stats.reset_index()

with pd.option_context('display.min_rows', 20,
                       'display.max_columns', None,
                       'display.precision', 3,
                       ):
    print(predicate_stats)
# Out:
#            subject                           object  count  \
# 0         Activity                         Activity      1
# 1         Activity                       Annotation      1
# 2         Activity                BiologicalProcess      1
# 3         Activity                   ChemicalEntity      1
# 4         Activity                 ChemicalExposure      1
# 5         Activity                ClinicalAttribute      1
# 6         Activity             ClinicalIntervention      1
# 7         Activity          ComplexMolecularMixture      1
# 8         Activity                           Device      1
# 9         Activity                          Disease      1
# ..             ...                              ...    ...
# 672  SmallMolecule                       Phenomenon      1
# 673  SmallMolecule                PhenotypicFeature     16
# 674  SmallMolecule             PhysiologicalProcess      9
# 675  SmallMolecule                      Polypeptide     13
# 676  SmallMolecule  PopulationOfIndividualOrganisms      1
# 677  SmallMolecule                        Procedure      8
# 678  SmallMolecule                          Protein      7
# 679  SmallMolecule                      Publication      1
# 680  SmallMolecule                    SmallMolecule     21
# 681      Treatment                          Disease      1
#
#                                                   list
# 0                                    [correlated_with]
# 1                                    [correlated_with]
# 2                                    [correlated_with]
# 3                                    [correlated_with]
# 4                                    [correlated_with]
# 5                                    [correlated_with]
# 6                                    [correlated_with]
# 7                                    [correlated_with]
# 8                                    [correlated_with]
# 9                                    [correlated_with]
# ..                                                 ...
# 672                                           [causes]
# 673  [treats, correlated_with, causes, ameliorates,...
# 674  [correlated_with, causes, disrupts, affects, e...
# 675  [subclass_of, superclass_of, part_of, interact...
# 676                                  [correlated_with]
# 677  [correlated_with, causes, positively_correlate...
# 678  [subclass_of, correlated_with, increases_trans...
# 679                                  [correlated_with]
# 680  [subclass_of, superclass_of, correlated_with, ...
# 681                                       [related_to]
#
# [682 rows x 4 columns]

# %%
predicate_stats.to_csv("results/predicate_stats.tsv", sep="\t")

# %% [markdown]
# ## Filter by most common types

# %% [markdown]
# Filter to only include the most common types of entities.  Also, since we _mostly_ have the same info in both directions, only keep one direction to simplify visualization

# %%
NUM_TYPES_TO_KEEP = 10

keep = set(pd.concat([predicate_stats['subject'], predicate_stats['object']]).value_counts().head(NUM_TYPES_TO_KEEP).keys())
keep
# Out:
# {'BiologicalProcess',
#  'ChemicalEntity',
#  'Disease',
#  'Gene',
#  'MolecularMixture',
#  'PhenotypicFeature',
#  'PhysiologicalProcess',
#  'Procedure',
#  'Protein',
#  'SmallMolecule'}

# %%
predicate_stats_filt = predicate_stats.query("subject in @keep & object in @keep & subject <= object")
predicate_stats_filt.to_csv("results/predicate_stats_filt.tsv", sep="\t")
predicate_stats_filt
# Out:
#                   subject                object  count  \
# 56      BiologicalProcess     BiologicalProcess     10
# 57      BiologicalProcess        ChemicalEntity      1
# 62      BiologicalProcess               Disease      3
# 65      BiologicalProcess                  Gene      3
# 69      BiologicalProcess      MolecularMixture      1
# 71      BiologicalProcess     PhenotypicFeature      2
# 72      BiologicalProcess  PhysiologicalProcess      1
# 74      BiologicalProcess             Procedure      1
# 75      BiologicalProcess               Protein      6
# 77      BiologicalProcess         SmallMolecule      1
# 114        ChemicalEntity        ChemicalEntity     12
# 121        ChemicalEntity               Disease     15
# 124        ChemicalEntity                  Gene     44
# 128        ChemicalEntity      MolecularMixture      4
# 132        ChemicalEntity     PhenotypicFeature     10
# 133        ChemicalEntity  PhysiologicalProcess      6
# 136        ChemicalEntity             Procedure      3
# 137        ChemicalEntity               Protein      3
# 139        ChemicalEntity         SmallMolecule     11
# 258               Disease               Disease     36
# 262               Disease                  Gene     21
# 266               Disease      MolecularMixture      9
# 269               Disease     PhenotypicFeature     17
# 270               Disease  PhysiologicalProcess     10
# 273               Disease             Procedure     15
# 274               Disease               Protein      5
# 277               Disease         SmallMolecule     23
# 344                  Gene                  Gene     32
# 349                  Gene      MolecularMixture     30
# 353                  Gene     PhenotypicFeature     12
# 354                  Gene  PhysiologicalProcess      7
# 356                  Gene             Procedure      1
# 357                  Gene               Protein     10
# 360                  Gene         SmallMolecule     61
# 434      MolecularMixture      MolecularMixture      3
# 436      MolecularMixture     PhenotypicFeature      8
# 437      MolecularMixture  PhysiologicalProcess      2
# 440      MolecularMixture             Procedure      2
# 441      MolecularMixture               Protein      2
# 443      MolecularMixture         SmallMolecule      4
# 492     PhenotypicFeature     PhenotypicFeature     13
# 493     PhenotypicFeature  PhysiologicalProcess      4
# 496     PhenotypicFeature             Procedure     12
# 497     PhenotypicFeature               Protein      3
# 500     PhenotypicFeature         SmallMolecule     16
# 522  PhysiologicalProcess  PhysiologicalProcess      8
# 525  PhysiologicalProcess             Procedure      4
# 526  PhysiologicalProcess               Protein      5
# 528  PhysiologicalProcess         SmallMolecule      9
# 590             Procedure             Procedure      8
# 591             Procedure               Protein      1
# 593             Procedure         SmallMolecule      8
# 620               Protein               Protein      5
# 622               Protein         SmallMolecule      7
# 680         SmallMolecule         SmallMolecule     21
#
#                                                   list
# 56   [subclass_of, superclass_of, process_negativel...
# 57                                   [correlated_with]
# 62       [subclass_of, superclass_of, correlated_with]
# 65   [correlated_with, actively_involves, has_parti...
# 69                                   [correlated_with]
# 71                    [superclass_of, correlated_with]
# 72                                   [correlated_with]
# 74                                   [correlated_with]
# 75   [actively_involved_in, correlated_with, preced...
# 77                                   [correlated_with]
# 114  [subclass_of, superclass_of, correlated_with, ...
# 121  [treats, biomarker_for, correlated_with, ameli...
# 124  [correlated_with, regulates, directly_physical...
# 128  [subclass_of, superclass_of, correlated_with, ...
# 132  [treats, correlated_with, causes, ameliorates,...
# 133  [correlated_with, causes, produced_by, entity_...
# 136             [correlated_with, causes, preceded_by]
# 137  [superclass_of, correlated_with, increases_tra...
# 139  [subclass_of, superclass_of, correlated_with, ...
# 258  [contributes_to, has_phenotype, phenotype_of, ...
# 262  [has_biomarker, phenotype_of, contribution_fro...
# 266  [has_biomarker, treated_by, correlated_with, i...
# 269  [subclass_of, has_phenotype, correlated_with, ...
# 270  [correlated_with, contains_process, associated...
# 273  [correlated_with, positively_correlated_with, ...
# 274  [correlated_with, contribution_from, is_amelio...
# 277  [has_biomarker, treated_by, correlated_with, i...
# 344  [orthologous_to, superclass_of, biomarker_for,...
# 349  [correlated_with, regulated_by, directly_physi...
# 353  [has_phenotype, correlated_with, genetic_assoc...
# 354  [correlated_with, genetic_association, causes,...
# 356                                  [correlated_with]
# 357  [correlated_with, increases_secretion_of, resp...
# 360  [correlated_with, regulated_by, directly_physi...
# 434           [subclass_of, superclass_of, similar_to]
# 436  [treats, correlated_with, causes, ameliorates,...
# 437                          [correlated_with, causes]
# 440                          [correlated_with, causes]
# 441          [correlated_with, increases_transport_of]
# 443  [subclass_of, superclass_of, correlated_with, ...
# 492  [subclass_of, superclass_of, correlated_with, ...
# 493  [correlated_with, associated_with, causes, man...
# 496  [correlated_with, positively_correlated_with, ...
# 497  [correlated_with, contribution_from, is_amelio...
# 500  [treated_by, correlated_with, caused_by, affec...
# 522  [correlated_with, coexists_with, affects, affe...
# 525  [correlated_with, affected_by, entity_positive...
# 526  [correlated_with, produces, disrupted_by, affe...
# 528  [correlated_with, caused_by, disrupted_by, aff...
# 590  [correlated_with, positively_correlated_with, ...
# 591                                  [correlated_with]
# 593  [correlated_with, caused_by, positively_correl...
# 620  [similar_to, subclass_of, superclass_of, corre...
# 622  [superclass_of, correlated_with, affects_abund...
# 680  [subclass_of, superclass_of, correlated_with, ...

# %%
api_stats_filt = api_stats.query("subject in @keep & object in @keep & subject <= object")
api_stats_filt.to_csv("results/api_stats_filt.tsv", sep="\t")
api_stats_filt
# Out:
#                   subject                object  count  \
# 56      BiologicalProcess     BiologicalProcess      5
# 57      BiologicalProcess        ChemicalEntity      1
# 62      BiologicalProcess               Disease      3
# 65      BiologicalProcess                  Gene      3
# 69      BiologicalProcess      MolecularMixture      1
# 71      BiologicalProcess     PhenotypicFeature      3
# 72      BiologicalProcess  PhysiologicalProcess      1
# 74      BiologicalProcess             Procedure      1
# 75      BiologicalProcess               Protein      3
# 77      BiologicalProcess         SmallMolecule      1
# 114        ChemicalEntity        ChemicalEntity      8
# 121        ChemicalEntity               Disease      6
# 124        ChemicalEntity                  Gene      7
# 128        ChemicalEntity      MolecularMixture      7
# 132        ChemicalEntity     PhenotypicFeature      5
# 133        ChemicalEntity  PhysiologicalProcess      3
# 136        ChemicalEntity             Procedure      3
# 137        ChemicalEntity               Protein      7
# 139        ChemicalEntity         SmallMolecule      8
# 258               Disease               Disease     11
# 262               Disease                  Gene     16
# 266               Disease      MolecularMixture      5
# 269               Disease     PhenotypicFeature     11
# 270               Disease  PhysiologicalProcess      2
# 273               Disease             Procedure      4
# 274               Disease               Protein      3
# 277               Disease         SmallMolecule     14
# 344                  Gene                  Gene     15
# 349                  Gene      MolecularMixture      5
# 353                  Gene     PhenotypicFeature      8
# 354                  Gene  PhysiologicalProcess      3
# 356                  Gene             Procedure      1
# 357                  Gene               Protein      5
# 360                  Gene         SmallMolecule     14
# 434      MolecularMixture      MolecularMixture      6
# 436      MolecularMixture     PhenotypicFeature      4
# 437      MolecularMixture  PhysiologicalProcess      2
# 440      MolecularMixture             Procedure      2
# 441      MolecularMixture               Protein      2
# 443      MolecularMixture         SmallMolecule      7
# 492     PhenotypicFeature     PhenotypicFeature      9
# 493     PhenotypicFeature  PhysiologicalProcess      2
# 496     PhenotypicFeature             Procedure      4
# 497     PhenotypicFeature               Protein      2
# 500     PhenotypicFeature         SmallMolecule      9
# 522  PhysiologicalProcess  PhysiologicalProcess      2
# 525  PhysiologicalProcess             Procedure      2
# 526  PhysiologicalProcess               Protein      2
# 528  PhysiologicalProcess         SmallMolecule      3
# 590             Procedure             Procedure      3
# 591             Procedure               Protein      1
# 593             Procedure         SmallMolecule      5
# 620               Protein               Protein      5
# 622               Protein         SmallMolecule      7
# 680         SmallMolecule         SmallMolecule     12
#
#                                                   list
# 56   [Automat-viral-proteome(Trapi v1.3.0), Automat...
# 57                    [Automat-icees-kg(Trapi v1.3.0)]
# 62   [Automat-viral-proteome(Trapi v1.3.0), Automat...
# 65   [Automat-icees-kg(Trapi v1.3.0), Automat-hetio...
# 69                    [Automat-icees-kg(Trapi v1.3.0)]
# 71   [Automat-viral-proteome(Trapi v1.3.0), Automat...
# 72                    [Automat-icees-kg(Trapi v1.3.0)]
# 74                    [Automat-icees-kg(Trapi v1.3.0)]
# 75   [Automat-viral-proteome(Trapi v1.3.0), Automat...
# 77                    [Automat-icees-kg(Trapi v1.3.0)]
# 114  [Automat-biolink(Trapi v1.3.0), Automat-icees-...
# 121  [Automat-biolink(Trapi v1.3.0), Automat-icees-...
# 124  [Automat-icees-kg(Trapi v1.3.0), Automat-hetio...
# 128  [Automat-biolink(Trapi v1.3.0), Automat-icees-...
# 132  [Automat-biolink(Trapi v1.3.0), Automat-icees-...
# 133  [Automat-icees-kg(Trapi v1.3.0), Automat-hetio...
# 136  [Automat-icees-kg(Trapi v1.3.0), Automat-hetio...
# 137  [Automat-biolink(Trapi v1.3.0), Automat-viral-...
# 139  [Automat-biolink(Trapi v1.3.0), Automat-icees-...
# 258  [Automat-biolink(Trapi v1.3.0), Ontology Looku...
# 262  [Automat-biolink(Trapi v1.3.0), Automat-icees-...
# 266  [Automat-biolink(Trapi v1.3.0), Automat-icees-...
# 269  [Automat-biolink(Trapi v1.3.0), Automat-icees-...
# 270  [Automat-icees-kg(Trapi v1.3.0), BioThings SEM...
# 273  [Automat-icees-kg(Trapi v1.3.0), COHD TRAPI 1....
# 274  [Automat-icees-kg(Trapi v1.3.0), Automat-ctd(T...
# 277  [Automat-biolink(Trapi v1.3.0), Automat-icees-...
# 344  [Automat-biolink(Trapi v1.3.0), Automat-hetio(...
# 349  [Automat-icees-kg(Trapi v1.3.0), Automat-hetio...
# 353  [Automat-biolink(Trapi v1.3.0), Automat-icees-...
# 354  [Automat-icees-kg(Trapi v1.3.0), Automat-pharo...
# 356                   [Automat-icees-kg(Trapi v1.3.0)]
# 357  [Automat-icees-kg(Trapi v1.3.0), Automat-ctd(T...
# 360  [Automat-icees-kg(Trapi v1.3.0), Automat-hetio...
# 434  [Automat-biolink(Trapi v1.3.0), Automat-hetio(...
# 436  [Automat-biolink(Trapi v1.3.0), Automat-icees-...
# 437  [Automat-icees-kg(Trapi v1.3.0), Automat-hetio...
# 440  [Automat-icees-kg(Trapi v1.3.0), Automat-hetio...
# 441  [Automat-icees-kg(Trapi v1.3.0), Automat-hmdb(...
# 443  [Automat-biolink(Trapi v1.3.0), Automat-icees-...
# 492  [Automat-biolink(Trapi v1.3.0), Automat-icees-...
# 493  [Automat-icees-kg(Trapi v1.3.0), BioThings SEM...
# 496  [Automat-icees-kg(Trapi v1.3.0), COHD TRAPI 1....
# 497  [Automat-icees-kg(Trapi v1.3.0), Automat-ctd(T...
# 500  [Automat-biolink(Trapi v1.3.0), Automat-icees-...
# 522  [Automat-icees-kg(Trapi v1.3.0), BioThings SEM...
# 525  [Automat-icees-kg(Trapi v1.3.0), BioThings SEM...
# 526  [Automat-icees-kg(Trapi v1.3.0), BioThings SEM...
# 528  [Automat-icees-kg(Trapi v1.3.0), Automat-hetio...
# 590  [Automat-icees-kg(Trapi v1.3.0), COHD TRAPI 1....
# 591                   [Automat-icees-kg(Trapi v1.3.0)]
# 593  [Automat-icees-kg(Trapi v1.3.0), Automat-hetio...
# 620  [Automat-viral-proteome(Trapi v1.3.0), Automat...
# 622  [Automat-biolink(Trapi v1.3.0), Automat-icees-...
# 680  [Automat-biolink(Trapi v1.3.0), Automat-icees-...

# %% [markdown]
# ## Export to graphml

# %%
def create_graph(df2, filename):
    G = nx.Graph()

    node_types = set(pd.concat([df2['subject'], df2['object']]))
        
    for node_type in node_types:
        G.add_node(node_type, label = add_spacing(node_type))

    for index,row in df2.iterrows():
        G.add_edge(row['subject'], row['object'], weight=row['count'])
    
    nx.write_graphml(G, filename, infer_numeric_types=True)

# %%
def add_spacing(str):
    key = {
        "BiologicalProcess":               "Biological\nProcess",
        "ChemicalEntity":                  "Chemical\nEntity",
        "MolecularMixture":                "Molecular\nMixture", 
        "PhysiologicalProcess":            "Physiological\nProcess",
        "SmallMolecule":                   "Small\nMolecule",
        "PhenotypicFeature":               "Phenotypic\nFeature",
        'ChemicalExposure':                'Chemical\nExposure',
        'ClinicalAttribute':               'Clinical\nAttribute',
        'ClinicalIntervention':            'Clinical\nIntervention',
        'ComplexMolecularMixture':         'Complex\nMolecular\nMixture',
        'EnvironmentalExposure':           'Environmental\nExposure',
        'InformationContentEntity':        'Information\nContentEntity',
        'MolecularMixture':                'Molecular\nMixture',
        'PhysiologicalProcess':            'Physiological\nProcess',
        'PopulationOfIndividualOrganisms': 'PopulationOf\nIndividualOrganisms'
    }
    if str in key.keys():
        return(key[str])
    else:
        return(str)

# %%
create_graph(api_stats_filt, "results/api_stats_filt.graphml")
create_graph(predicate_stats_filt, "results/predicate_stats_filt.graphml")
